# %% [markdown]
# ## Pre-built Model
#
# This model will use a dataset generated on this code based on timeseries data.
#
# https://github.com/BenjiKCF/Neural-Net-with-Financial-Time-Series-Data/blob/master/5.%20Recurrent%20Neural%20Network.ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

url="https://gitlab.com/ivan.jesus.torres/pmrl-tesla/-/raw/main/Datasets/Generated%20datasets/forecasting.csv"
df_ann = pd.read_csv(url)

print(df_ann.head())
# Out:
#                   date       close        high  ...     DMP_14  DMN_14  TTM_TRND_6
# 0  2020-04-14 13:00:00  146.417999  148.376007  ...  82.036626     0.0           1
# 1  2020-04-14 14:00:00  144.806000  147.459991  ...  59.184050     0.0           1
# 2  2020-04-14 15:00:00  145.809998  146.990005  ...  52.542707     0.0           1
# 3  2020-04-14 16:00:00  146.475006  147.395981  ...  50.223569     0.0           1
# 4  2020-04-14 17:00:00  145.565002  147.736404  ...  46.857649     0.0           1
#
# [5 rows x 18 columns]

# %%
time_vector = list(df_ann['date'])
print(time_vector)
# Out:
# ['2020-04-14 13:00:00', '2020-04-14 14:00:00', '2020-04-14 15:00:00', '2020-04-14 16:00:00', '2020-04-14 17:00:00', '2020-04-14 18:00:00', '2020-04-14 19:00:00', '2020-04-15 13:00:00', '2020-04-15 14:00:00', '2020-04-15 15:00:00', '2020-04-15 16:00:00', '2020-04-15 17:00:00', '2020-04-15 18:00:00', '2020-04-15 19:00:00', '2020-04-16 13:00:00', '2020-04-16 14:00:00', '2020-04-16 15:00:00', '2020-04-16 16:00:00', '2020-04-16 17:00:00', '2020-04-16 18:00:00', '2020-04-16 19:00:00', '2020-04-17 13:00:00', '2020-04-17 14:00:00', '2020-04-17 15:00:00', '2020-04-17 16:00:00', '2020-04-17 17:00:00', '2020-04-17 18:00:00', '2020-04-17 19:00:00', '2020-04-20 13:00:00', '2020-04-20 14:00:00', '2020-04-20 15:00:00', '2020-04-20 16:00:00', '2020-04-20 17:00:00', '2020-04-20 18:00:00', '2020-04-20 19:00:00', '2020-04-21 13:00:00', '2020-04-21 14:00:00', '2020-04-21 15:00:00', '2020-04-21 16:00:00', '2020-04-21 17:00:00', '2020-04-21 18:00:00', '2020-04-21 19:00:00', '2020-04-22 13:00:00', '2020-04-22 14:00:00', '2020-04-22 15:00:00', '2020-04-22 16:00:00', '2020-04-22 17:00:00', '2020-04-22 18:00:00', '2020-04-22 19:00:00', '2020-04-23 13:00:00', '2020-04-23 14:00:00', '2020-04-23 15:00:00', '2020-04-23 16:00:00', '2020-04-23 17:00:00', '2020-04-23 18:00:00', '2020-04-23 19:00:00', '2020-04-24 13:00:00', '2020-04-24 14:00:00', '2020-04-24 15:00:00', '2020-04-24 16:00:00', '2020-04-24 17:00:00', '2020-04-24 18:00:00', '2020-04-24 19:00:00', '2020-04-27 13:00:00', '2020-04-27 14:00:00', '2020-04-27 15:00:00', '2020-04-27 16:00:00', '2020-04-27 17:00:00', '2020-04-27 18:00:00', '2020-04-27 19:00:00', '2020-04-28 13:00:00', '2020-04-28 14:00:00', '2020-04-28 15:00:00', '2020-04-28 16:00:00', '2020-04-28 17:00:00', '2020-04-28 18:00:00', '2020-04-28 19:00:00', '2020-04-29 13:00:00', '2020-04-29 14:00:00', '2020-04-29 15:00:00', '2020-04-29 16:00:00', '2020-04-29 17:00:00', '2020-04-29 18:00:00', '2020-04-29 19:00:00', '2020-04-30 13:00:00', '2020-04-30 14:00:00', '2020-04-30 15:00:00', '2020-04-30 16:00:00', '2020-04-30 17:00:00', '2020-04-30 18:00:00', '2020-04-30 19:00:00', '2020-05-01 13:00:00', '2020-05-01 14:00:00', '2020-05-01 15:00:00', '2020-05-01 16:00:00', '2020-05-01 17:00:00', '2020-05-01 18:00:00', '2020-05-01 19:00:00', '2020-05-04 13:00:00', '2020-05-04 14:00:00', '2020-05-04 15:00:00', '2020-05-04 16:00:00', '2020-05-04 17:00:00', '2020-05-04 18:00:00', '2020-05-04 19:00:00', '2020-05-05 13:00:00', '2020-05-05 14:00:00', '2020-05-05 15:00:00', '2020-05-05 16:00:00', '2020-05-05 17:00:00', '2020-05-05 18:00:00', '2020-05-05 19:00:00', '2020-05-06 13:00:00', '2020-05-06 14:00:00', '2020-05-06 15:00:00', '2020-05-06 16:00:00', '2020-05-06 17:00:00', '2020-05-06 18:00:00', '2020-05-06 19:00:00', '2020-05-07 13:00:00', '2020-05-07 14:00:00', '2020-05-07 15:00:00', '2020-05-07 16:00:00', '2020-05-07 17:00:00', '2020-05-07 18:00:00', '2020-05-07 19:00:00', '2020-05-08 13:00:00', '2020-05-08 14:00:00', '2020-05-08 15:00:00', '2020-05-08 16:00:00', '2020-05-08 17:00:00', '2020-05-08 18:00:00', '2020-05-08 19:00:00', '2020-05-11 13:00:00', '2020-05-11 14:00:00', '2020-05-11 15:00:00', '2020-05-11 16:00:00', '2020-05-11 17:00:00', '2020-05-11 18:00:00', '2020-05-11 19:00:00', '2020-05-12 13:00:00', '2020-05-12 14:00:00', '2020-05-12 15:00:00', '2020-05-12 16:00:00', '2020-05-12 17:00:00', '2020-05-12 18:00:00', '2020-05-12 19:00:00', '2020-05-13 13:00:00', '2020-05-13 14:00:00', '2020-05-13 15:00:00', '2020-05-13 16:00:00', '2020-05-13 17:00:00', '2020-05-13 18:00:00', '2020-05-13 19:00:00', '2020-05-14 13:00:00', '2020-05-14 14:00:00', '2020-05-14 15:00:00', '2020-05-14 16:00:00', '2020-05-14 17:00:00', '2020-05-14 18:00:00', '2020-05-14 19:00:00', '2020-05-15 13:00:00', '2020-05-15 14:00:00', '2020-05-15 15:00:00', '2020-05-15 16:00:00', '2020-05-15 17:00:00', '2020-05-15 18:00:00', '2020-05-15 19:00:00', '2020-05-18 13:00:00', '2020-05-18 14:00:00', '2020-05-18 15:00:00', '2020-05-18 16:00:00', '2020-05-18 17:00:00', '2020-05-18 18:00:00 ...

# %%
df_ann.shape
# Out:
# (1741, 18)

# %%
df_ann.head(1)
# Out:
#                   date       close        high  ...     DMP_14  DMN_14  TTM_TRND_6
# 0  2020-04-14 13:00:00  146.417999  148.376007  ...  82.036626     0.0           1
#
# [1 rows x 18 columns]

# %%
titles = [
    "Close",
    "High",
    "Low",
    "Volume",
    "Pytrends",
    "BBL_5_2.0",
    "BBM_5_2.0",
    "BBU_5_2.0",
    "BBB_5_2.0",
    "RSI_14",
    "MACD_12_26_9",
    "MACDh_12_26_9",
    "MACDs_12_26_9",
    "ADX_14",
    "DMP_14",
    "DMN_14",
    "TTM_TRND_6",
]

feature_keys = [
    "close",
    "high",
    "low",
    "volume",
    "tesla",
    "BBL_5_2.0",
    "BBM_5_2.0",
    "BBU_5_2.0",
    "BBB_5_2.0",
    "RSI_14",
    "MACD_12_26_9",
    "MACDh_12_26_9",
    "MACDs_12_26_9",
    "ADX_14",
    "DMP_14",
    "DMN_14",
    "TTM_TRND_6",
]

colors = [
    "blue",
    "orange",
    "green",
    "red",
    "purple",
    "brown",
    "pink",
    "gray",
    "olive",
    "cyan",
    "blue",
    "orange",
    "green",
    "red",
    "purple",
    "brown",
    "pink",
]

# %%
final_dataset = df_ann.values
print(final_dataset)
# Out:
# [['2020-04-14 13:00:00' 146.41799926757812 148.37600708007812 ...
#   82.03662616800874 0.0 1]
#  ['2020-04-14 14:00:00' 144.80599975585938 147.45999145507812 ...
#   59.18404993096201 0.0 1]
#  ['2020-04-14 15:00:00' 145.80999755859375 146.99000549316406 ...
#   52.542707014034136 0.0 1]
#  ...
#  ['2021-04-09 17:00:00' 672.2484741210938 678.489990234375 ...
#   8.724925265169142 28.76674492586141 -1]
#  ['2021-04-09 18:00:00' 674.3499755859375 675.1434936523438 ...
#   7.858872548389728 26.925962265490185 -1]
#  ['2021-04-09 19:00:00' 677.02001953125 677.489990234375 ...
#   12.984387880942169 24.862114565405715 1]]

# %%
date_time_key = "date"
def show_raw_visualization(data):
    time_data = data[date_time_key]
    fig, axes = plt.subplots(
        nrows=9, ncols=2, figsize=(15, 20), dpi=80, facecolor="w", edgecolor="k"
    )
    for i in range(len(feature_keys)):
        key = feature_keys[i]
        c = colors[i % (len(colors))]
        t_data = data[key]
        t_data.index = time_data
        t_data.head()
        ax = t_data.plot(
            ax=axes[i // 2, i % 2],
            color=c,
            title="{} - {}".format(titles[i], key),
            rot=25,
        )
        ax.legend([titles[i]])
    plt.tight_layout()


show_raw_visualization(df_ann)

# %%
def show_heatmap(data):
    plt.matshow(data.corr())
    plt.xticks(range(data.shape[1]), data.columns, fontsize=14, rotation=90)
    plt.gca().xaxis.tick_bottom()
    plt.yticks(range(data.shape[1]), data.columns, fontsize=14)

    cb = plt.colorbar()
    cb.ax.tick_params(labelsize=14)
    plt.title("Feature Correlation Heatmap", fontsize=14)
    plt.show()


show_heatmap(df_ann[feature_keys])

# %% [markdown]
# ## Variables declaration
#
# Definition of some variables to generate the datasets and to train the model.

# %%
split_fraction = 0.8 # 80% of data for training
train_split = int(split_fraction * int(df_ann.shape[0]))
step = 1 # How much time passes between data. We have data every hour so 1

past = 5*6 # Number of days * 6 hours (Time that the market is open - 1 hour)=> Use data from 30 previous hours
future = 1 #Do the prediction 1 hour after the actual hour
learning_rate = 0.00000001 #Learning rate
batch_size = 80 #256
epochs = 80000 #800

# %% [markdown]
# ## Select variables to use
#
# According to the correlation map to predict the close value we will use the high, low and the BBL, BBM, BBU values. To them we will add the pytrends value and the volume because they do not have a very low correlation to the close value and we consider them important.

# %%
import numpy as np
selec=np.array([0,1,2,3,4,5,6,7])
print(selec+1)
print(selec.size)
# Out:
# [1 2 3 4 5 6 7 8]
# 8

# %% [markdown]
# Checking variables

# %%
#print(final_dataset.shape)
final_no_date=final_dataset[:,selec+1]
#print(final_no_date)

# %% [markdown]
# ## Scaling data

# %%
from sklearn.preprocessing import MinMaxScaler

print(
    "The selected parameters are:",
    ", ".join([titles[i] for i in selec]),
)
selected_features = [feature_keys[i] for i in selec]
features = df_ann[selected_features]
features.index = df_ann[date_time_key]
print(features.head())
features=features.values

scaler = MinMaxScaler(feature_range=(0, 1))

features = pd.DataFrame(features[:,:])
features[features.columns] = scaler.fit_transform(features[features.columns]) # Scale features by columns (as univariable)

print(features.shape)
print(features.head())

features_scaled_w_date=pd.DataFrame(features)
features_scaled_w_date.insert(0,"date",df_ann[date_time_key])

#print(features_scaled_w_date.head())

train_data = features.loc[0 : train_split - 1]

#print(train_data)

val_data = features.loc[train_split:]
# Out:
# The selected parameters are: Close, High, Low, Volume, Pytrends, BBL_5_2.0, BBM_5_2.0, BBU_5_2.0
#                           close        high  ...   BBM_5_2.0   BBU_5_2.0
# date                                         ...
# 2020-04-14 13:00:00  146.417999  148.376007  ...  141.118793  147.043486
# 2020-04-14 14:00:00  144.806000  147.459991  ...  142.121194  148.595632
# 2020-04-14 15:00:00  145.809998  146.990005  ...  143.324396  149.872011
# 2020-04-14 16:00:00  146.475006  147.395981  ...  144.660599  150.264763
# 2020-04-14 17:00:00  145.565002  147.736404  ...  145.814801  147.185867
#
# [5 rows x 8 columns]
# (1741, 8)
#           0         1         2  ...         5         6         7
# 0  0.012035  0.011395  0.005281  ...  0.002011  0.001545  0.006420
# 1  0.009897  0.010191  0.008711  ...  0.002616  0.002882  0.008474
# 2  0.011229  0.009573  0.012813  ...  0.004123  0.004487  0.010164
# 3  0.012111  0.010107  0.014405  ...  0.007165  0.006270  0.010684
# 4  0.010904  0.010555  0.014223  ...  0.014354  0.007809  0.006608
#
# [5 rows x 8 columns]

# %%
print(features[4])
selec.size
# Out:
# 0       0.898734
# 1       1.000000
# 2       0.911392
# 3       0.860759
# 4       0.911392
#           ...
# 1736    0.632911
# 1737    0.620253
# 1738    0.620253
# 1739    0.670886
# 1740    0.734177
# Name: 4, Length: 1741, dtype: float64
# 8

# %% [markdown]
# ## Prepare train split

# %%
start = past + future
end = start + train_split
print([i+1 for i in range(selec.size)])
x_train = train_data[[i for i in range(selec.size)]].values
#print(x_train)
print(features.head())
y_train = features.iloc[start:end][0]
#print(y_train)
sequence_length = int(past / step)
print(sequence_length)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
#                   date         0         1  ...         5         6         7
# 0  2020-04-14 13:00:00  0.012035  0.011395  ...  0.002011  0.001545  0.006420
# 1  2020-04-14 14:00:00  0.009897  0.010191  ...  0.002616  0.002882  0.008474
# 2  2020-04-14 15:00:00  0.011229  0.009573  ...  0.004123  0.004487  0.010164
# 3  2020-04-14 16:00:00  0.012111  0.010107  ...  0.007165  0.006270  0.010684
# 4  2020-04-14 17:00:00  0.010904  0.010555  ...  0.014354  0.007809  0.006608
#
# [5 rows x 9 columns]
# 30

# %% [markdown]
# Checking variables

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (1392, 8)
# (1392,)

# %% [markdown]
# Use keras.preprocessing.timeseries_dataset_from_array to generate the training set.

# %%
dataset_train = keras.preprocessing.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=batch_size,
)

# %% [markdown]
# ## Generate test split

# %%
x_end = len(val_data) - past - future

label_start = train_split + past + future

x_val = val_data.iloc[:x_end][[i for i in range(selec.size)]].values
print(x_val.shape)
y_val = features.iloc[label_start:][[0]]
print(y_val.shape)
dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    x_val,
    y_val,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=batch_size,
)
print(dataset_val)

for batch in dataset_train.take(1):
    inputs, targets = batch

print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)
# Out:
# (318, 8)
# (318, 1)
# <BatchDataset shapes: ((None, None, 8), (None, 1)), types: (tf.float64, tf.float64)>
# Input shape: (80, 30, 8)
# Target shape: (80,)

# %%
print(x_val.shape)
# Out:
# (318, 8)

# %%
inputs.shape[2]
# Out:
# 8

# %% [markdown]
# ## Build model

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization
model = Sequential()
model.add(LSTM(256, input_shape=(inputs.shape[1], inputs.shape[2]), return_sequences=True))
model.add(BatchNormalization())  #normalizes activation outputs, same reason you want to normalize your input data.

model.add(LSTM(128, return_sequences=True))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(LSTM(64))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(1, activation='tanh'))

opt = tf.keras.optimizers.RMSprop(lr=7e-3)
model.compile(loss='mse',optimizer=opt, metrics=['mse'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30, 256)           271360
# _________________________________________________________________
# batch_normalization (BatchNo (None, 30, 256)           1024
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30, 128)           197120
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 128)           512
# _________________________________________________________________
# dropout (Dropout)            (None, 30, 128)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 32)                2080
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32)                128
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 521,921
# Trainable params: 520,961
# Non-trainable params: 960
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
print(inputs.shape[1])
# Out:
# 30

# %%
print(dataset_train)
# Out:
# <BatchDataset shapes: ((None, None, 8), (None,)), types: (tf.float64, tf.float64)>

# %%
path_checkpoint = "model_checkpoint.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_mse", min_delta=0.0000002, patience=50)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_mse",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
    callbacks=[es_callback, modelckpt_callback],
)
# Out:
# Epoch 1/80000
# 18/18 [==============================] - 13s 378ms/step - loss: 0.3597 - mse: 0.3597 - val_loss: 0.0115 - val_mse: 0.0115
#
# Epoch 00001: val_mse improved from inf to 0.01147, saving model to model_checkpoint.h5
# Epoch 2/80000
# 18/18 [==============================] - 6s 315ms/step - loss: 0.2357 - mse: 0.2357 - val_loss: 0.0108 - val_mse: 0.0108
#
# Epoch 00002: val_mse improved from 0.01147 to 0.01081, saving model to model_checkpoint.h5
# Epoch 3/80000
# 18/18 [==============================] - 6s 317ms/step - loss: 0.1696 - mse: 0.1696 - val_loss: 0.0452 - val_mse: 0.0452
#
# Epoch 00003: val_mse did not improve from 0.01081
# Epoch 4/80000
# 18/18 [==============================] - 6s 315ms/step - loss: 0.1248 - mse: 0.1248 - val_loss: 0.0723 - val_mse: 0.0723
#
# Epoch 00004: val_mse did not improve from 0.01081
# Epoch 5/80000
# 18/18 [==============================] - 6s 311ms/step - loss: 0.1028 - mse: 0.1028 - val_loss: 0.0406 - val_mse: 0.0406
#
# Epoch 00005: val_mse did not improve from 0.01081
# Epoch 6/80000
# 18/18 [==============================] - 6s 318ms/step - loss: 0.0901 - mse: 0.0901 - val_loss: 0.0238 - val_mse: 0.0238
#
# Epoch 00006: val_mse did not improve from 0.01081
# Epoch 7/80000
# 18/18 [==============================] - 6s 315ms/step - loss: 0.0956 - mse: 0.0956 - val_loss: 0.0470 - val_mse: 0.0470
#
# Epoch 00007: val_mse did not improve from 0.01081
# Epoch 8/80000
# 18/18 [==============================] - 6s 318ms/step - loss: 0.0922 - mse: 0.0922 - val_loss: 0.0303 - val_mse: 0.0303
#
# Epoch 00008: val_mse did not improve from 0.01081
# Epoch 9/80000
# 18/18 [==============================] - 6s 314ms/step - loss: 0.0905 - mse: 0.0905 - val_loss: 0.0251 - val_mse: 0.0251
#
# Epoch 00009: val_mse did not improve from 0.01081
# Epoch 10/80000
# 18/18 [==============================] - 6s 314ms/step - loss: 0.0896 - mse: 0.0896 - val_loss: 0.0336 - val_mse: 0.0336
#
# Epoch 00010: val_mse did not improve from 0.01081
# Epoch 11/80000
# 18/18 [==============================] - 6s 313ms/step - loss: 0.0897 - mse: 0.0897 - val_loss: 0.0136 - val_mse: 0.0136
#
# Epoch 00011: val_mse did not improve from 0.01081
# Epoch 12/80000
# 18/18 [==============================] - 6s 316ms/step - loss: 0.0854 - mse: 0.0854 - val_loss: 0.0145 - val_mse: 0.0145
#
# Epoch 00012: val_mse did not improve from 0.01081
# Epoch 13/80000
# 18/18 [==============================] - 6s 317ms/step - loss: 0.0896 - mse: 0.0896 - val_loss: 0.0169 - val_mse: 0.0169
#
# Epoch 00013: val_mse did not improve from 0.01081
# Epoch 14/80000
# 18/18 [==============================] - 6s 319ms/step - loss: 0.0862 - mse: 0.0862 - val_loss: 0.0740 - val_mse: 0.0740
#
# Epoch 00014: val_mse did not improve from 0.01081
# Epoch 15/80000
# 18/18 [==============================] - 6s 318ms/step - loss: 0.0906 - mse: 0.0906 - val_loss: 0.0095 - val_mse: 0.0095
#
# Epoch 00015: val_mse improved from 0.01081 to 0.00950, saving model to model_checkpoint.h5
# Epoch 16/80000
# 18/18 [==============================] - 6s 320ms/step - loss: 0.0893 - mse: 0.0893 - val_loss: 0.0120 - val_mse: 0.0120
#
# Epoch 00016: val_mse did not improve from 0.00950
# Epoch 17/80000
# 18/18 [==============================] - 6s 316ms/step - loss: 0.0889 - mse: 0.0889 - val_loss: 0.0185 - val_mse: 0.0185
#
# Epoch 00017: val_mse did not improve from 0.00950
# Epoch 18/80000
# 18/18 [==============================] - 6s 325ms/step - loss: 0.0905 - mse: 0.0905 - val_loss: 0.0135 - val_mse: 0.0135
#
# Epoch 00018: val_mse did not improve from 0.00950
# Epoch 19/80000
# 18/18 [==============================] - 6s 318ms/step - loss: 0.0869 - mse: 0.0869 - val_loss: 0.0162 - val_mse: 0.0162
#
# Epoch 00019: val_mse did not improve from 0.00950
# Epoch 20/80000
# 18/18 [==============================] - 6s 317ms/step - loss: 0.0891 - mse: 0.0891 - val_loss: 0.0146 - val_mse: 0.0146
#
# Epoch 00020: val_mse did not improve from 0.00950
# Epoch 21/80000
# 18/18 [==============================] - 6s 316ms/step - loss: 0.0897 - mse: 0.0897 - val_loss: 0.0137 - val_mse: 0.0137
#
# Epoch 00021: val_mse did not improve from 0.00950
# Epoch 22/80000
# 18/18 [==============================] - 6s 315ms/step - loss: 0.0880 - mse: 0.0880 - val_loss: 0.0095 - val_mse: 0.0095
#
# Epoch 00022: val_mse improved from 0.00950 to 0.00946, saving model to model_checkpoint.h5
# Epoch 23/80000
# 18/18 [==============================] - 6s 324ms/step - loss: 0.0878 - mse: 0.0878 - val_loss: 0.0135 - val_mse: 0.0135
#
# Epoch 00023: val_mse did not improve from 0.00946
# Epoch 24/80000
# 18/18 [==============================] - 6s 321ms/step - loss: 0.0870 - mse: 0.0870 - val_loss: 0.0154 - val_mse: 0.0154
#
# Epoch 00024: val_mse did not improve from 0.00946
# Epoch 25/80000
# 18/18 [==============================] - 6s 322ms/step - loss: 0.0882 - mse: 0.0882 - val_loss: 0.0216 - val_mse: 0.0216
#
# Epoch 00025: val_mse did not improve from 0.00946
# Epoch 26/80000
# 18/18 [==============================] - 6s 317ms/step - loss: 0.0896 - mse: 0.0896 - val_loss: 0.0958 - val_mse: 0.0958
#
# Epoch 00026: val_mse did not improve from 0.00946
# Epoch 27/80000
# 18/18 [==============================] - 6s 316ms/step - loss: 0.0870 - mse: 0.0870 - val_loss: 0.0318 - val_mse: 0.0318
#
# Epoch 00027: val_mse did not improve from 0.00946
# Epoch 28/80000
# 18/18 [==============================] - 6s 320ms/step - loss: 0.0891 - mse: 0.0891 - val_loss: 0.0092 - val_mse: 0.0092
#
# Epoch 00028: val_mse improved from 0.00946 to 0.00921, saving model to model_checkpoint.h5
# Epoch 29/80000
# 18/18 [==============================] - 6s 316ms/step - loss: 0.0869 - mse: 0.0869 - val_loss: 0.0165 - val_mse: 0.0165
#
# Epoch 00029: val_mse did not improve from 0.00921
# Epoch 30/80000
# 18/18 [==============================] - 6s 319ms/step - loss: 0.0882 - mse: 0.0882 - val_loss: 0.0290 - val_mse: 0.0290
#
# Epoch 00030: val_mse did not improve from 0.00921
# Epoch 31/80000
# 18/18 [==============================] - 6s 318ms/step - loss: 0.0873 - mse: 0.0873 - val_loss: 0.0265 - val_mse: 0.0265
#
# Epoch 00031: val_mse did not improve from 0.00921
# Epoch 32/80000
# 18/18 [==============================] - 6s 318ms/step - loss: 0.0870 - mse: 0.0870 - val_loss: 0.0258 - val_mse: 0.0258
#
# Epoch 00032: val_mse did not improve from 0.00921
# Epoch 33/80000
# 18/18 [==============================] - 6s 317ms/step - loss: 0.0891 - mse: 0.0891 - val_loss: 0.0128 - val_mse: 0.0128
#
# Epoch 00033: val_mse did not improve from 0.00921
# Epoch 34/80000
# 18/18 [==============================] - 6s 315ms/step - loss: 0.0879 - mse: 0.0879 - val_loss: 0.0152 - val_mse: 0.0152
#
# Epoch 00034: val_mse did not improve from 0.00921
# Epoch 35/80000
# 18/18 [==============================] - 6s 317ms/step - loss: 0.0875 - mse: 0.0875 - val_loss: 0.0142 - val_mse: 0.0142
#
# Epoch 00035: val_mse did not improve from 0.00921
# Epoch 36/80000
# 18/18 [==============================] - 6s 322ms/step - loss: 0.0874 - mse: 0.0874 - val_loss: 0.0145 - val_mse: 0.0145
#
# Epoch 00036: val_mse did not improve from 0.00921
# Epoch 37/80000
# 18/18 [==============================] - 6s 319ms/step - loss: 0.0876 - mse: 0.0876 - val_loss: 0.0118 - val_mse: 0.0118
#
# Epoch 00037: val_mse did not improve from 0.00921
# Epoch 38/80000
# 18/18 [==============================] - 6s 313ms/step - loss: 0.0880 - mse: 0.0880 - val_loss: 0.2401 - val_mse: 0.2401
#
# Epoch 00038: val_mse did not improve from 0.00921
# Epoch 39/80000
# 18/18 [==============================] - 6s 321ms/step - loss: 0.0853 - mse: 0.0853 - val_loss: 0.0102 - val_mse: 0.0102
#
# Epoch 00039: val_mse did not improve from 0.00921
# Epoch 40/80000
# 18/18 [==============================] - 6s 316ms/step - loss: 0.0866 - mse: 0.0866 - val_loss: 0.0540 - val_mse: 0.0540
#
# Epoch 00040: val_mse did not improve from 0.00921
# Epoch 41/80000
# 18/18 [==============================] - 6s 322ms/step - loss: 0.0858 - mse: 0.0858 - val_loss: 0.0316 - val_mse: 0.0316
#
# Epoch 00041: val_mse did not improve from 0.00921
# Epoch 42/80000
# 18/18 [==============================] - 6s 316ms/step - loss: 0.0853 - mse: 0.0853 - val_loss: 0.0103 - val_mse: 0.0103
#
# Epoch 00042: val_mse did not improve from 0.00921
# Epoch 43/80000
# 18/18 [==============================] - 6s 319ms/step - loss: 0.0864 - mse: 0.0864 - val_loss: 0.0334 - val_mse: 0.0334
#
# Epoch 00043: val_mse did not improve from 0.00921
# Epoch 44/80000
# 18/18 [==============================] - 6s 318ms/step - loss: 0.0848 - mse: 0.0848 - val_loss: 0.0501 - val_mse: 0.0501
#
# Epoch 00044: val_mse did not improve from 0.00921
# Epoch 45/80000
# 18/18 [==============================] - 6s 314ms/step - loss: 0.0856 - mse: 0.0856 - val_loss: 0.0120 - val_mse: 0.0120
#
# Epoch 00045: val_mse did not improve from 0.00921
# Epoch 46/80000
# 18/18 [==============================] - 6s 321ms/step - loss: 0.0862 - mse: 0.0862 - val_loss: 0.0394 - val_mse: 0.0394
#
# Epoch 00046: val_mse did not improve from 0.00921
# Epoch 47/80000
# 18/18 [==============================] - 6s 321ms/step - loss: 0.0865 - mse: 0.0865 - val_loss: 0.0839 - val_mse: 0.0839
#
# Epoch 00047: val_mse did not improve from 0.00921
# Epoch 48/80000
# 18/18 [==============================] - 6s 319ms/step - loss: 0.0847 - mse: 0.0847 - val_loss: 0.0317 - val_mse: 0.0317
#
# Epoch 00048: val_mse did not improve from 0.00921
# Epoch 49/80000
# 18/18 [==============================] - 6s 314ms/step - loss: 0.0857 - mse: 0.0857 - val_loss: 0.0274 - val_mse: 0.0274
#
# Epoch 00049: val_mse did not improve from 0.00921
# Epoch 50/80000
# 18/18 [==============================] - 6s 315ms/step - loss: 0.0848 - mse: 0.0848 - val_loss: 0.0643 - val_mse: 0.0643
#
# Epoch 00050: val_mse did not improve from 0.00921
# Epoch 51/80000
# 18/18 [==============================] - 6s 320ms/step - loss: 0.0829 - mse: 0.0829 - val_loss: 0.0645 - val_mse: 0.0645
#
# Epoch 00051: val_mse did not improve from 0.00921
# Epoch 52/80000
# 18/18 [==============================] - 6s 321ms/step - loss: 0.0849 - mse: 0.0849 - val_loss: 0.1031 - val_mse: 0.1031
#
# Epoch 00052: val_mse did not improve from 0.00921
# Epoch 53/80000
# 18/18 [==============================] - 6s 316ms/step - loss: 0.0826 - mse: 0.0826 - val_loss: 0.0355 - val_mse: 0.0355
#
# Epoch 00053: val_mse did not improve from 0.00921
# Epoch 54/80000
# 18/18 [==============================] - 6s 319ms/step - loss: 0.0830 - mse: 0.0830 - val_loss: 0.0502 - val_mse: 0.0502
#
# Epoch 00054: val_mse did not improve from 0.00921
# Epoch 55/80000
# 18/18 [==============================] - 6s 318ms/step - loss: 0.0849 - mse: 0.0849 - val_loss: 0.0834 - val_mse: 0.0834
#
# Epoch 00055: val_mse did not improve from 0.00921
# Epoch 56/80000
# 18/18 [==============================] - 6s 323ms/step - loss: 0.0825 - mse: 0.0825 - val_loss: 0.0365 - val_mse: 0.0365
#
# Epoch 00056: val_mse did not improve from 0.00921
# Epoch 57/80000
# 18/18 [==============================] - 6s 316ms/step - loss: 0.0822 - mse: 0.0822 - val_loss: 0.0328 - val_mse: 0.0328
#
# Epoch 00057: val_mse did not improve from 0.00921
# Epoch 58/80000
# 18/18 [==============================] - 6s 320ms/step - loss: 0.0829 - mse: 0.0829 - val_loss: 0.0506 - val_mse: 0.0506
#
# Epoch 00058: val_mse did not improve from 0.00921
# Epoch 59/80000
# 18/18 [==============================] - 6s 320ms/step - loss: 0.0806 - mse: 0.0806 - val_loss: 0.0637 - val_mse: 0.0637
#
# Epoch 00059: val_mse did not improve from 0.00921
# Epoch 60/80000
# 18/18 [==============================] - 6s 317ms/step - loss: 0.0824 - mse: 0.0824 - val_loss: 0.1481 - val_mse: 0.1481
#
# Epoch 00060: val_mse did not improve from 0.00921
# Epoch 61/80000
# 18/18 [==============================] - 6s 319ms/step - loss: 0.0843 - mse: 0.0843 - val_loss: 0.0313 - val_mse: 0.0313
#
# Epoch 00061: val_mse did not improve from 0.00921
# Epoch 62/80000
# 18/18 [==============================] - 6s 322ms/step - loss: 0.0821 - mse: 0.0821 - val_loss: 0.0882 - val_mse: 0.0882
#
# Epoch 00062: val_mse did not improve from 0.00921
# Epoch 63/80000
# 18/18 [==============================] - 6s 318ms/step - loss: 0.0821 - mse: 0.0821 - val_loss: 0.0358 - val_mse: 0.0358
#
# Epoch 00063: val_mse did not improve from 0.00921
# Epoch 64/80000
# 18/18 [==============================] - 6s 318ms/step - loss: 0.0816 - mse: 0.0816 - val_loss: 0.0350 - val_mse: 0.0350
#
# Epoch 00064: val_mse did not improve from 0.00921
# Epoch 65/80000
# 18/18 [==============================] - 6s 318ms/step - loss: 0.0824 - mse: 0.0824 - val_loss: 0.0679 - val_mse: 0.0679
#
# Epoch 00065: val_mse did not improve from 0.00921
# Epoch 66/80000
# 18/18 [==============================] - 6s 320ms/step - loss: 0.0815 - mse: 0.0815 - val_loss: 0.0821 - val_mse: 0.0821
#
# Epoch 00066: val_mse did not improve from 0.00921
# Epoch 67/80000
# 18/18 [==============================] - 6s 322ms/step - loss: 0.0786 - mse: 0.0786 - val_loss: 0.0595 - val_mse: 0.0595
#
# Epoch 00067: val_mse did not improve from 0.00921
# Epoch 68/80000
# 18/18 [==============================] - 6s 319ms/step - loss: 0.0827 - mse: 0.0827 - val_loss: 0.0646 - val_mse: 0.0646
#
# Epoch 00068: val_mse did not improve from 0.00921
# Epoch 69/80000
# 18/18 [==============================] - 6s 322ms/step - loss: 0.0807 - mse: 0.0807 - val_loss: 0.0613 - val_mse: 0.0613
#
# Epoch 00069: val_mse did not improve from 0.00921
# Epoch 70/80000
# 18/18 [==============================] - 6s 318ms/step - loss: 0.0803 - mse: 0.0803 - val_loss: 0.0822 - val_mse: 0.0822
#
# Epoch 00070: val_mse did not improve from 0.00921
# Epoch 71/80000
# 18/18 [==============================] - 6s 322ms/step - loss: 0.0806 - mse: 0.0806 - val_loss: 0.0515 - val_mse: 0.0515
#
# Epoch 00071: val_mse did not improve from 0.00921
# Epoch 72/80000
# 18/18 [==============================] - 6s 321ms/step - loss: 0.0810 - mse: 0.0810 - val_loss: 0.0529 - val_mse: 0.0529
#
# Epoch 00072: val_mse did not improve from 0.00921
# Epoch 73/80000
# 18/18 [==============================] - 6s 318ms/step - loss: 0.0798 - mse: 0.0798 - val_loss: 0.0431 - val_mse: 0.0431
#
# Epoch 00073: val_mse did not improve from 0.00921
# Epoch 74/80000
# 18/18 [==============================] - 6s 319ms/step - loss: 0.0809 - mse: 0.0809 - val_loss: 0.0677 - val_mse: 0.0677
#
# Epoch 00074: val_mse did not improve from 0.00921
# Epoch 75/80000
# 18/18 [==============================] - 6s 319ms/step - loss: 0.0802 - mse: 0.0802 - val_loss: 0.0829 - val_mse: 0.0829
#
# Epoch 00075: val_mse did not improve from 0.00921
# Epoch 76/80000
# 18/18 [==============================] - 6s 328ms/step - loss: 0.0807 - mse: 0.0807 - val_loss: 0.1018 - val_mse: 0.1018
#
# Epoch 00076: val_mse did not improve from 0.00921
# Epoch 77/80000
# 18/18 [==============================] - 6s 320ms/step - loss: 0.0794 - mse: 0.0794 - val_loss: 0.0871 - val_mse: 0.0871
#
# Epoch 00077: val_mse did not improve from 0.00921
# Epoch 78/80000
# 18/18 [==============================] - 6s 321ms/step - loss: 0.0808 - mse: 0.0808 - val_loss: 0.0781 - val_mse: 0.0781
#
# Epoch 00078: val_mse did not improve from 0.00921

# %% [markdown]
# ## Visualize train and test loss

# %%
def visualize_loss(history, title):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(loss))
    plt.figure()
    plt.plot(epochs, loss, "b", label="Training loss")
    plt.plot(epochs, val_loss, "r", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()


visualize_loss(history, "Training and Validation Loss")

# %% [markdown]
# Checking variables

# %%
dataset_val
# Out:
# <BatchDataset shapes: ((None, None, 8), (None, 1)), types: (tf.float64, tf.float64)>

# %%
time_data = df_ann[date_time_key]
print(time_data)
# Out:
# 0       2020-04-14 13:00:00
# 1       2020-04-14 14:00:00
# 2       2020-04-14 15:00:00
# 3       2020-04-14 16:00:00
# 4       2020-04-14 17:00:00
#                ...
# 1736    2021-04-09 15:00:00
# 1737    2021-04-09 16:00:00
# 1738    2021-04-09 17:00:00
# 1739    2021-04-09 18:00:00
# 1740    2021-04-09 19:00:00
# Name: date, Length: 1741, dtype: object

# %%
print(train_split+sequence_length)
print(label_start)
# Out:
# 1422
# 1423

# %%
print(train_split)
# Out:
# 1392

# %% [markdown]
# Plot test close data

# %%
import matplotlib.ticker as ticker
dates_for_plot=time_data[label_start+sequence_length-1:] #Get testing data dates
print(dates_for_plot.shape)
t_data=df_ann["close"] # Get testing data close values
print(t_data[label_start+sequence_length-1:])
ax = plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(15))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(5))
plt.xticks(rotation=90,fontsize=10)
plt.subplots_adjust(top=51,bottom = 50)
plt.plot(t_data[label_start+sequence_length-1:])
# Out:
# (289,)
# date
# 2021-02-09 19:00:00    844.684998
# 2021-02-09 20:00:00    849.250000
# 2021-02-10 14:00:00    817.729980
# 2021-02-10 15:00:00    813.619995
# 2021-02-10 16:00:00    813.900024
#                           ...
# 2021-04-09 15:00:00    676.549988
# 2021-04-09 16:00:00    678.255005
# 2021-04-09 17:00:00    672.248474
# 2021-04-09 18:00:00    674.349976
# 2021-04-09 19:00:00    677.020020
# Name: close, Length: 289, dtype: float64

# %% [markdown]
# ## Predict
#
# Predict the data in the dataset and inverse scale it.

# %%
y_hat=[]
y_hat_un=[]
for x, y in dataset_val:
    x_num=x.numpy()
    #print(x_num)
    x_num_shape=x_num.shape
    print(x_num_shape)
    #print(x[x_num_shape[0]-1,:,:])
    for j in range(x_num_shape[0]):
      x_ten=x[j,:,:]
      #print(x_ten)
      x_ten_re=tf.reshape(x_ten, [1,past,selec.size], name=None)
      #print(x_ten_re)
      #print(model.predict(x_ten_re))
      y_=model.predict(x_ten_re)
      y_hat.append(y_)
      x_un=scaler.inverse_transform(pd.DataFrame(x_ten))
      y_scaled=np.zeros([selec.size,selec.size])
      y_scaled[0]=y_
      y_un=scaler.inverse_transform(pd.DataFrame(y_scaled))[0,0]
      y_hat_un.append(y_un)
      #print(x_un)
      #print(y_un)
      #input("Press Enter to continue...")
    #print(model.predict(x_ten))
    #print(y)

#x_ten=x[x_num_shape[0]-1,:,:]
#x_ten_re=tf.reshape(x_ten, [1,30,15], name=None)
#print(x_ten_re)
#x_num=x.numpy()
#x_num_shape=x_num.shape
#print(model.predict(x_ten_re))
#print(y[x_num_shape[0]-1])
# Out:
# (80, 30, 8)
# (80, 30, 8)
# (80, 30, 8)
# (49, 30, 8)

# %%
#print(y_hat)

# %%
print(len(y_hat))
# Out:
# 289

# %%
#Image_FORECASTING_LSTM_1_3_0
import numpy as np
y_hat_un_np=np.array(y_hat_un)
ax = plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(15))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(5))
plt.xticks(rotation=90,fontsize=10)
plt.subplots_adjust(top=51,bottom = 50)
plt.plot(dates_for_plot,y_hat_un_np[:],'c.',label="Prediction")
plt.plot(dates_for_plot,t_data[label_start+sequence_length-1:],'g*',label="Real")
variation=y_hat_un_np[:]-t_data[label_start+sequence_length-1:]
print(variation)
plt.legend()
# Out:
# date
# 2021-02-09 19:00:00   -331.339833
# 2021-02-09 20:00:00   -335.894926
# 2021-02-10 14:00:00   -304.346034
# 2021-02-10 15:00:00   -300.265685
# 2021-02-10 16:00:00   -300.548748
#                           ...
# 2021-04-09 15:00:00   -163.298273
# 2021-04-09 16:00:00   -165.014390
# 2021-04-09 17:00:00   -159.080008
# 2021-04-09 18:00:00   -161.184408
# 2021-04-09 19:00:00   -163.845757
# Name: close, Length: 289, dtype: float64

# %% [markdown]
# ## Aplication
#
# Compute the prediction for the given date and show the prediction and the real data.

# %%
from datetime import datetime
dt = datetime.strptime('2021-03-22 16:00:00', '%Y-%m-%d %H:%M:%S')
mask = (features_scaled_w_date['date'] <= str(dt))
#print(features_scaled_w_date.shape)
features_scaled_w_date_tensor=features_scaled_w_date.loc[mask]
#print(features_scaled_w_date_tensor.shape)
dates_plot=features_scaled_w_date_tensor.iloc[-sequence_length-future-1:,:]
features_scaled_w_date_tensor=features_scaled_w_date_tensor.iloc[-sequence_length-future-1:-future-1,:]
#print(features_scaled_w_date_tensor.head())
tensor_single=tf.convert_to_tensor(features_scaled_w_date_tensor.iloc[:,1:])
#print(tensor_single)
x_ten_re_s=tf.reshape(tensor_single, [1,past,selec.size], name=None)


y_s=model.predict(x_ten_re_s)
x_un_s=scaler.inverse_transform(features_scaled_w_date_tensor.iloc[:,1:])
y_target=scaler.inverse_transform(dates_plot.iloc[:,1:])[sequence_length+future,0]

y_scaled_single=np.zeros([selec.size,selec.size])
y_scaled_single[0]=y_s
y_un_single=scaler.inverse_transform(pd.DataFrame(y_scaled_single))[0,0]
#print(x_un_s)
#print(y_un_single)

x_for_plot=x_un_s[:,0]
#print(dates_plot.head())
dates_1=dates_plot['date']
ax = plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(5))
plt.xticks(rotation=90,fontsize=10)
plt.subplots_adjust(top=51,bottom = 50)
plt.plot(dates_1[0:sequence_length],x_for_plot)
print(dates_1.iloc[sequence_length+future])
plt.plot(dates_1.iloc[sequence_length+future],y_un_single,'bo',label="Prediction")
print(y_target)
plt.plot(dates_1.iloc[sequence_length+future],y_target,'ro',label="Real")
plt.legend()
# Out:
# 2021-03-22 16:00:00
# 690.2000732421875

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from math import sqrt
rmse = sqrt(mean_squared_error(t_data[label_start+sequence_length-1:], y_hat_un_np))
print('Test RMSE: %.3f' % rmse)
# Calculate MAE
mae = mean_absolute_error(t_data[label_start+sequence_length-1:], y_hat_un_np)
print('Test MAE: %.3f' % mae)
# r2
from sklearn.metrics import r2_score
test_r2 = r2_score(t_data[label_start+sequence_length-1:], y_hat_un_np)
print('Test r2: %.3f' % test_r2)
# Out:
# Test RMSE: 188.758
# Test MAE: 178.844
# Test r2: -8.762

# %%
print(x_un_s.shape)
# Out:
# (30, 8)

# %%
#print(dates_for_plot[0:1363])
y_hat_np=np.array(y_hat)
ax = plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(15))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(5))
plt.xticks(rotation=90,fontsize=10)
plt.subplots_adjust(top=51,bottom = 50)
print(y_hat_np.shape)
print(dates_for_plot.shape)
plt.plot(dates_for_plot,y_hat_np[:,0,0])
print(features.tail())
print(features.loc[label_start+sequence_length-1 : ,0])
plt.plot(dates_for_plot,features.loc[label_start+sequence_length-1 : ,0])
# Out:
# (289, 1, 1)
# (289,)
#                      date         0         1  ...         5         6         7
# 1736  2021-04-09 15:00:00  0.715179  0.707214  ...  0.716668  0.715299  0.713900
# 1737  2021-04-09 16:00:00  0.717440  0.708765  ...  0.716583  0.715428  0.714241
# 1738  2021-04-09 17:00:00  0.709473  0.708279  ...  0.714247  0.713955  0.713634
# 1739  2021-04-09 18:00:00  0.712261  0.703880  ...  0.714087  0.713181  0.712258
# 1740  2021-04-09 19:00:00  0.715802  0.706964  ...  0.716873  0.714677  0.712461
#
# [5 rows x 9 columns]
# 1452    0.938185
# 1453    0.944240
# 1454    0.902433
# 1455    0.896982
# 1456    0.897353
#           ...
# 1736    0.715179
# 1737    0.717440
# 1738    0.709473
# 1739    0.712261
# 1740    0.715802
# Name: 0, Length: 289, dtype: float64
