# %% [markdown]
# ## LSTM Model
#
# This model will use a dataset generated on this code based on timeseries data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

url="https://gitlab.com/ivan.jesus.torres/pmrl-tesla/-/raw/main/Datasets/Generated%20datasets/forecasting.csv"
df_ann = pd.read_csv(url)

print(df_ann.head())
# Out:
#                   date       close        high  ...     DMP_14  DMN_14  TTM_TRND_6
# 0  2020-04-14 13:00:00  146.417999  148.376007  ...  82.036626     0.0           1
# 1  2020-04-14 14:00:00  144.806000  147.459991  ...  59.184050     0.0           1
# 2  2020-04-14 15:00:00  145.809998  146.990005  ...  52.542707     0.0           1
# 3  2020-04-14 16:00:00  146.475006  147.395981  ...  50.223569     0.0           1
# 4  2020-04-14 17:00:00  145.565002  147.736404  ...  46.857649     0.0           1
#
# [5 rows x 18 columns]

# %%
time_vector = list(df_ann['date'])
print(time_vector)
# Out:
# ['2020-04-14 13:00:00', '2020-04-14 14:00:00', '2020-04-14 15:00:00', '2020-04-14 16:00:00', '2020-04-14 17:00:00', '2020-04-14 18:00:00', '2020-04-14 19:00:00', '2020-04-15 13:00:00', '2020-04-15 14:00:00', '2020-04-15 15:00:00', '2020-04-15 16:00:00', '2020-04-15 17:00:00', '2020-04-15 18:00:00', '2020-04-15 19:00:00', '2020-04-16 13:00:00', '2020-04-16 14:00:00', '2020-04-16 15:00:00', '2020-04-16 16:00:00', '2020-04-16 17:00:00', '2020-04-16 18:00:00', '2020-04-16 19:00:00', '2020-04-17 13:00:00', '2020-04-17 14:00:00', '2020-04-17 15:00:00', '2020-04-17 16:00:00', '2020-04-17 17:00:00', '2020-04-17 18:00:00', '2020-04-17 19:00:00', '2020-04-20 13:00:00', '2020-04-20 14:00:00', '2020-04-20 15:00:00', '2020-04-20 16:00:00', '2020-04-20 17:00:00', '2020-04-20 18:00:00', '2020-04-20 19:00:00', '2020-04-21 13:00:00', '2020-04-21 14:00:00', '2020-04-21 15:00:00', '2020-04-21 16:00:00', '2020-04-21 17:00:00', '2020-04-21 18:00:00', '2020-04-21 19:00:00', '2020-04-22 13:00:00', '2020-04-22 14:00:00', '2020-04-22 15:00:00', '2020-04-22 16:00:00', '2020-04-22 17:00:00', '2020-04-22 18:00:00', '2020-04-22 19:00:00', '2020-04-23 13:00:00', '2020-04-23 14:00:00', '2020-04-23 15:00:00', '2020-04-23 16:00:00', '2020-04-23 17:00:00', '2020-04-23 18:00:00', '2020-04-23 19:00:00', '2020-04-24 13:00:00', '2020-04-24 14:00:00', '2020-04-24 15:00:00', '2020-04-24 16:00:00', '2020-04-24 17:00:00', '2020-04-24 18:00:00', '2020-04-24 19:00:00', '2020-04-27 13:00:00', '2020-04-27 14:00:00', '2020-04-27 15:00:00', '2020-04-27 16:00:00', '2020-04-27 17:00:00', '2020-04-27 18:00:00', '2020-04-27 19:00:00', '2020-04-28 13:00:00', '2020-04-28 14:00:00', '2020-04-28 15:00:00', '2020-04-28 16:00:00', '2020-04-28 17:00:00', '2020-04-28 18:00:00', '2020-04-28 19:00:00', '2020-04-29 13:00:00', '2020-04-29 14:00:00', '2020-04-29 15:00:00', '2020-04-29 16:00:00', '2020-04-29 17:00:00', '2020-04-29 18:00:00', '2020-04-29 19:00:00', '2020-04-30 13:00:00', '2020-04-30 14:00:00', '2020-04-30 15:00:00', '2020-04-30 16:00:00', '2020-04-30 17:00:00', '2020-04-30 18:00:00', '2020-04-30 19:00:00', '2020-05-01 13:00:00', '2020-05-01 14:00:00', '2020-05-01 15:00:00', '2020-05-01 16:00:00', '2020-05-01 17:00:00', '2020-05-01 18:00:00', '2020-05-01 19:00:00', '2020-05-04 13:00:00', '2020-05-04 14:00:00', '2020-05-04 15:00:00', '2020-05-04 16:00:00', '2020-05-04 17:00:00', '2020-05-04 18:00:00', '2020-05-04 19:00:00', '2020-05-05 13:00:00', '2020-05-05 14:00:00', '2020-05-05 15:00:00', '2020-05-05 16:00:00', '2020-05-05 17:00:00', '2020-05-05 18:00:00', '2020-05-05 19:00:00', '2020-05-06 13:00:00', '2020-05-06 14:00:00', '2020-05-06 15:00:00', '2020-05-06 16:00:00', '2020-05-06 17:00:00', '2020-05-06 18:00:00', '2020-05-06 19:00:00', '2020-05-07 13:00:00', '2020-05-07 14:00:00', '2020-05-07 15:00:00', '2020-05-07 16:00:00', '2020-05-07 17:00:00', '2020-05-07 18:00:00', '2020-05-07 19:00:00', '2020-05-08 13:00:00', '2020-05-08 14:00:00', '2020-05-08 15:00:00', '2020-05-08 16:00:00', '2020-05-08 17:00:00', '2020-05-08 18:00:00', '2020-05-08 19:00:00', '2020-05-11 13:00:00', '2020-05-11 14:00:00', '2020-05-11 15:00:00', '2020-05-11 16:00:00', '2020-05-11 17:00:00', '2020-05-11 18:00:00', '2020-05-11 19:00:00', '2020-05-12 13:00:00', '2020-05-12 14:00:00', '2020-05-12 15:00:00', '2020-05-12 16:00:00', '2020-05-12 17:00:00', '2020-05-12 18:00:00', '2020-05-12 19:00:00', '2020-05-13 13:00:00', '2020-05-13 14:00:00', '2020-05-13 15:00:00', '2020-05-13 16:00:00', '2020-05-13 17:00:00', '2020-05-13 18:00:00', '2020-05-13 19:00:00', '2020-05-14 13:00:00', '2020-05-14 14:00:00', '2020-05-14 15:00:00', '2020-05-14 16:00:00', '2020-05-14 17:00:00', '2020-05-14 18:00:00', '2020-05-14 19:00:00', '2020-05-15 13:00:00', '2020-05-15 14:00:00', '2020-05-15 15:00:00', '2020-05-15 16:00:00', '2020-05-15 17:00:00', '2020-05-15 18:00:00', '2020-05-15 19:00:00', '2020-05-18 13:00:00', '2020-05-18 14:00:00', '2020-05-18 15:00:00', '2020-05-18 16:00:00', '2020-05-18 17:00:00', '2020-05-18 18:00:00 ...

# %%
df_ann.shape
# Out:
# (1741, 18)

# %%
df_ann.head(1)
# Out:
#                   date       close        high  ...     DMP_14  DMN_14  TTM_TRND_6
# 0  2020-04-14 13:00:00  146.417999  148.376007  ...  82.036626     0.0           1
#
# [1 rows x 18 columns]

# %%
titles = [
    "Close",
    "High",
    "Low",
    "Volume",
    "Pytrends",
    "BBL_5_2.0",
    "BBM_5_2.0",
    "BBU_5_2.0",
    "BBB_5_2.0",
    "RSI_14",
    "MACD_12_26_9",
    "MACDh_12_26_9",
    "MACDs_12_26_9",
    "ADX_14",
    "DMP_14",
    "DMN_14",
    "TTM_TRND_6",
]

feature_keys = [
    "close",
    "high",
    "low",
    "volume",
    "tesla",
    "BBL_5_2.0",
    "BBM_5_2.0",
    "BBU_5_2.0",
    "BBB_5_2.0",
    "RSI_14",
    "MACD_12_26_9",
    "MACDh_12_26_9",
    "MACDs_12_26_9",
    "ADX_14",
    "DMP_14",
    "DMN_14",
    "TTM_TRND_6",
]

colors = [
    "blue",
    "orange",
    "green",
    "red",
    "purple",
    "brown",
    "pink",
    "gray",
    "olive",
    "cyan",
    "blue",
    "orange",
    "green",
    "red",
    "purple",
    "brown",
    "pink",
]

# %%
final_dataset = df_ann.values
print(final_dataset)
# Out:
# [['2020-04-14 13:00:00' 146.41799926757812 148.37600708007812 ...
#   82.03662616800874 0.0 1]
#  ['2020-04-14 14:00:00' 144.80599975585938 147.45999145507812 ...
#   59.18404993096201 0.0 1]
#  ['2020-04-14 15:00:00' 145.80999755859375 146.99000549316406 ...
#   52.542707014034136 0.0 1]
#  ...
#  ['2021-04-09 17:00:00' 672.2484741210938 678.489990234375 ...
#   8.724925265169142 28.76674492586141 -1]
#  ['2021-04-09 18:00:00' 674.3499755859375 675.1434936523438 ...
#   7.858872548389728 26.925962265490185 -1]
#  ['2021-04-09 19:00:00' 677.02001953125 677.489990234375 ...
#   12.984387880942169 24.862114565405715 1]]

# %%
date_time_key = "date"
def show_raw_visualization(data):
    time_data = data[date_time_key]
    fig, axes = plt.subplots(
        nrows=9, ncols=2, figsize=(15, 20), dpi=80, facecolor="w", edgecolor="k"
    )
    for i in range(len(feature_keys)):
        key = feature_keys[i]
        c = colors[i % (len(colors))]
        t_data = data[key]
        t_data.index = time_data
        t_data.head()
        ax = t_data.plot(
            ax=axes[i // 2, i % 2],
            color=c,
            title="{} - {}".format(titles[i], key),
            rot=25,
        )
        ax.legend([titles[i]])
    plt.tight_layout()


show_raw_visualization(df_ann)

# %%
def show_heatmap(data):
    plt.matshow(data.corr())
    plt.xticks(range(data.shape[1]), data.columns, fontsize=14, rotation=90)
    plt.gca().xaxis.tick_bottom()
    plt.yticks(range(data.shape[1]), data.columns, fontsize=14)

    cb = plt.colorbar()
    cb.ax.tick_params(labelsize=14)
    plt.title("Feature Correlation Heatmap", fontsize=14)
    plt.show()


show_heatmap(df_ann[feature_keys])

# %% [markdown]
# ## Variables declaration
#
# Definition of some variables to generate the datasets and to train the model.

# %%
split_fraction = 0.8 # 80% of data for training
train_split = int(split_fraction * int(df_ann.shape[0]))
step = 1 # How much time passes between data. We have data every hour so 1

past = 5*6 # Number of days * 6 hours (Time that the market is open - 1 hour)=> Use data from 30 previous hours
future = 1 #Do the prediction 1 hour after the actual hour
learning_rate = 0.000001 #Learning rate
batch_size = 256 #256
epochs = 80000 #800

# %% [markdown]
# ## Select variables to use
#
# According to the correlation map to predict the close value we will use the high, low and the BBL, BBM, BBU values. To them we will add the pytrends value and the volume because they do not have a very low correlation to the close value and we consider them important.

# %%
import numpy as np
selec=np.array([0,1,2,3,4,5,6,7])
print(selec+1)
print(selec.size)
# Out:
# [1 2 3 4 5 6 7 8]
# 8

# %% [markdown]
# Checking variables

# %%
#print(final_dataset.shape)
final_no_date=final_dataset[:,selec+1]
#print(final_no_date)

# %% [markdown]
# ## Scaling data

# %%
from sklearn.preprocessing import MinMaxScaler

print(
    "The selected parameters are:",
    ", ".join([titles[i] for i in selec]),
)
selected_features = [feature_keys[i] for i in selec]
features = df_ann[selected_features]
features.index = df_ann[date_time_key]
print(features.head())
features=features.values

scaler = MinMaxScaler(feature_range=(0, 1))

features = pd.DataFrame(features[:,:])
features[features.columns] = scaler.fit_transform(features[features.columns]) # Scale features by columns (as univariable)

print(features.shape)
print(features.head())

features_scaled_w_date=pd.DataFrame(features)
features_scaled_w_date.insert(0,"date",df_ann[date_time_key])

#print(features_scaled_w_date.head())

train_data = features.loc[0 : train_split - 1]

#print(train_data)

val_data = features.loc[train_split:]
# Out:
# The selected parameters are: Close, High, Low, Volume, Pytrends, BBL_5_2.0, BBM_5_2.0, BBU_5_2.0
#                           close        high  ...   BBM_5_2.0   BBU_5_2.0
# date                                         ...
# 2020-04-14 13:00:00  146.417999  148.376007  ...  141.118793  147.043486
# 2020-04-14 14:00:00  144.806000  147.459991  ...  142.121194  148.595632
# 2020-04-14 15:00:00  145.809998  146.990005  ...  143.324396  149.872011
# 2020-04-14 16:00:00  146.475006  147.395981  ...  144.660599  150.264763
# 2020-04-14 17:00:00  145.565002  147.736404  ...  145.814801  147.185867
#
# [5 rows x 8 columns]
# (1741, 8)
#           0         1         2  ...         5         6         7
# 0  0.012035  0.011395  0.005281  ...  0.002011  0.001545  0.006420
# 1  0.009897  0.010191  0.008711  ...  0.002616  0.002882  0.008474
# 2  0.011229  0.009573  0.012813  ...  0.004123  0.004487  0.010164
# 3  0.012111  0.010107  0.014405  ...  0.007165  0.006270  0.010684
# 4  0.010904  0.010555  0.014223  ...  0.014354  0.007809  0.006608
#
# [5 rows x 8 columns]

# %%
print(features[4])
selec.size
# Out:
# 0       0.898734
# 1       1.000000
# 2       0.911392
# 3       0.860759
# 4       0.911392
#           ...
# 1736    0.632911
# 1737    0.620253
# 1738    0.620253
# 1739    0.670886
# 1740    0.734177
# Name: 4, Length: 1741, dtype: float64
# 8

# %% [markdown]
# ## Prepare train split

# %%
start = past + future
end = start + train_split
print([i+1 for i in range(selec.size)])
x_train = train_data[[i for i in range(selec.size)]].values
#print(x_train)
print(features.head())
y_train = features.iloc[start:end][0]
#print(y_train)
sequence_length = int(past / step)
print(sequence_length)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
#                   date         0         1  ...         5         6         7
# 0  2020-04-14 13:00:00  0.012035  0.011395  ...  0.002011  0.001545  0.006420
# 1  2020-04-14 14:00:00  0.009897  0.010191  ...  0.002616  0.002882  0.008474
# 2  2020-04-14 15:00:00  0.011229  0.009573  ...  0.004123  0.004487  0.010164
# 3  2020-04-14 16:00:00  0.012111  0.010107  ...  0.007165  0.006270  0.010684
# 4  2020-04-14 17:00:00  0.010904  0.010555  ...  0.014354  0.007809  0.006608
#
# [5 rows x 9 columns]
# 30

# %% [markdown]
# Checking variables

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (1392, 8)
# (1392,)

# %% [markdown]
# Use keras.preprocessing.timeseries_dataset_from_array to generate the training set.

# %%
dataset_train = keras.preprocessing.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=batch_size,
)

# %% [markdown]
# ## Generate test split

# %%
x_end = len(val_data) - past - future

label_start = train_split + past + future

x_val = val_data.iloc[:x_end][[i for i in range(selec.size)]].values
print(x_val.shape)
y_val = features.iloc[label_start:][[0]]
print(y_val.shape)
dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    x_val,
    y_val,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=batch_size,
)
print(dataset_val)

for batch in dataset_train.take(1):
    inputs, targets = batch

print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)
# Out:
# (318, 8)
# (318, 1)
# <BatchDataset shapes: ((None, None, 8), (None, 1)), types: (tf.float64, tf.float64)>
# Input shape: (256, 30, 8)
# Target shape: (256,)

# %%
print(x_val.shape)
# Out:
# (318, 8)

# %%
inputs.shape[2]
# Out:
# 8

# %% [markdown]
# ## Build model

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization
model = keras.Sequential()
model.add(layers.Input(shape=(inputs.shape[1], inputs.shape[2])))
model.add(layers.LSTM(25,return_sequences=True))
model.add(Flatten())
model.add(layers.Dense(1))

model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse",metrics=[
        tf.keras.metrics.MeanSquaredError(),
    ])
model.summary()
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30, 25)            3400
# _________________________________________________________________
# module_wrapper (ModuleWrappe (None, 750)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 751
# =================================================================
# Total params: 4,151
# Trainable params: 4,151
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(inputs.shape[1])
# Out:
# 30

# %%
print(dataset_train)
# Out:
# <BatchDataset shapes: ((None, None, 8), (None,)), types: (tf.float64, tf.float64)>

# %%
path_checkpoint = "model_checkpoint.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0.0000002, patience=25)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
    callbacks=[es_callback, modelckpt_callback],
)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Epoch 972/80000
# 6/6 [==============================] - 0s 67ms/step - loss: 0.0465 - mean_squared_error: 0.0465 - val_loss: 0.1461 - val_mean_squared_error: 0.1461
#
# Epoch 00972: val_loss improved from 0.14657 to 0.14606, saving model to model_checkpoint.h5
# Epoch 973/80000
# 6/6 [==============================] - 0s 57ms/step - loss: 0.0464 - mean_squared_error: 0.0464 - val_loss: 0.1455 - val_mean_squared_error: 0.1455
#
# Epoch 00973: val_loss improved from 0.14606 to 0.14555, saving model to model_checkpoint.h5
# Epoch 974/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0462 - mean_squared_error: 0.0462 - val_loss: 0.1450 - val_mean_squared_error: 0.1450
#
# Epoch 00974: val_loss improved from 0.14555 to 0.14503, saving model to model_checkpoint.h5
# Epoch 975/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0460 - mean_squared_error: 0.0460 - val_loss: 0.1445 - val_mean_squared_error: 0.1445
#
# Epoch 00975: val_loss improved from 0.14503 to 0.14452, saving model to model_checkpoint.h5
# Epoch 976/80000
# 6/6 [==============================] - 0s 67ms/step - loss: 0.0459 - mean_squared_error: 0.0459 - val_loss: 0.1440 - val_mean_squared_error: 0.1440
#
# Epoch 00976: val_loss improved from 0.14452 to 0.14401, saving model to model_checkpoint.h5
# Epoch 977/80000
# 6/6 [==============================] - 0s 64ms/step - loss: 0.0457 - mean_squared_error: 0.0457 - val_loss: 0.1435 - val_mean_squared_error: 0.1435
#
# Epoch 00977: val_loss improved from 0.14401 to 0.14350, saving model to model_checkpoint.h5
# Epoch 978/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0456 - mean_squared_error: 0.0456 - val_loss: 0.1430 - val_mean_squared_error: 0.1430
#
# Epoch 00978: val_loss improved from 0.14350 to 0.14300, saving model to model_checkpoint.h5
# Epoch 979/80000
# 6/6 [==============================] - 0s 65ms/step - loss: 0.0454 - mean_squared_error: 0.0454 - val_loss: 0.1425 - val_mean_squared_error: 0.1425
#
# Epoch 00979: val_loss improved from 0.14300 to 0.14249, saving model to model_checkpoint.h5
# Epoch 980/80000
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0452 - mean_squared_error: 0.0452 - val_loss: 0.1420 - val_mean_squared_error: 0.1420
#
# Epoch 00980: val_loss improved from 0.14249 to 0.14198, saving model to model_checkpoint.h5
# Epoch 981/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0451 - mean_squared_error: 0.0451 - val_loss: 0.1415 - val_mean_squared_error: 0.1415
#
# Epoch 00981: val_loss improved from 0.14198 to 0.14148, saving model to model_checkpoint.h5
# Epoch 982/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0449 - mean_squared_error: 0.0449 - val_loss: 0.1410 - val_mean_squared_error: 0.1410
#
# Epoch 00982: val_loss improved from 0.14148 to 0.14098, saving model to model_checkpoint.h5
# Epoch 983/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0447 - mean_squared_error: 0.0447 - val_loss: 0.1405 - val_mean_squared_error: 0.1405
#
# Epoch 00983: val_loss improved from 0.14098 to 0.14048, saving model to model_checkpoint.h5
# Epoch 984/80000
# 6/6 [==============================] - 0s 67ms/step - loss: 0.0446 - mean_squared_error: 0.0446 - val_loss: 0.1400 - val_mean_squared_error: 0.1400
#
# Epoch 00984: val_loss improved from 0.14048 to 0.13997, saving model to model_checkpoint.h5
# Epoch 985/80000
# 6/6 [==============================] - 0s 57ms/step - loss: 0.0444 - mean_squared_error: 0.0444 - val_loss: 0.1395 - val_mean_squared_error: 0.1395
#
# Epoch 00985: val_loss improved from 0.13997 to 0.13948, saving model to model_checkpoint.h5
# Epoch 986/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0443 - mean_squared_error: 0.0443 - val_loss: 0.1390 - val_mean_squared_error: 0.1390
#
# Epoch 00986: val_loss improved from 0.13948 to 0.13898, saving model to model_checkpoint.h5
# Epoch 987/80000
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0441 - mean_squared_error: 0.0441 - val_loss: 0.1385 - val_mean_squared_error: 0.1385
#
# Epoch 00987: val_loss improved from 0.13898 to 0.13848, saving model to model_checkpoint.h5
# Epoch 988/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0439 - mean_squared_error: 0.0439 - val_loss: 0.1380 - val_mean_squared_error: 0.1380
#
# Epoch 00988: val_loss improved from 0.13848 to 0.13798, saving model to model_checkpoint.h5
# Epoch 989/80000
# 6/6 [==============================] - 0s 65ms/step - loss: 0.0438 - mean_squared_error: 0.0438 - val_loss: 0.1375 - val_mean_squared_error: 0.1375
#
# Epoch 00989: val_loss improved from 0.13798 to 0.13749, saving model to model_checkpoint.h5
# Epoch 990/80000
# 6/6 [==============================] - 0s 67ms/step - loss: 0.0436 - mean_squared_error: 0.0436 - val_loss: 0.1370 - val_mean_squared_error: 0.1370
#
# Epoch 00990: val_loss improved from 0.13749 to 0.13699, saving model to model_checkpoint.h5
# Epoch 991/80000
# 6/6 [==============================] - 0s 56ms/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.1365 - val_mean_squared_error: 0.1365
#
# Epoch 00991: val_loss improved from 0.13699 to 0.13650, saving model to model_checkpoint.h5
# Epoch 992/80000
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0433 - mean_squared_error: 0.0433 - val_loss: 0.1360 - val_mean_squared_error: 0.1360
#
# Epoch 00992: val_loss improved from 0.13650 to 0.13601, saving model to model_checkpoint.h5
# Epoch 993/80000
# 6/6 [==============================] - 0s 58ms/step - loss: 0.0431 - mean_squared_error: 0.0431 - val_loss: 0.1355 - val_mean_squared_error: 0.1355
#
# Epoch 00993: val_loss improved from 0.13601 to 0.13552, saving model to model_checkpoint.h5
# Epoch 994/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0430 - mean_squared_error: 0.0430 - val_loss: 0.1350 - val_mean_squared_error: 0.1350
#
# Epoch 00994: val_loss improved from 0.13552 to 0.13503, saving model to model_checkpoint.h5
# Epoch 995/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0428 - mean_squared_error: 0.0428 - val_loss: 0.1345 - val_mean_squared_error: 0.1345
#
# Epoch 00995: val_loss improved from 0.13503 to 0.13454, saving model to model_checkpoint.h5
# Epoch 996/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0427 - mean_squared_error: 0.0427 - val_loss: 0.1341 - val_mean_squared_error: 0.1341
#
# Epoch 00996: val_loss improved from 0.13454 to 0.13405, saving model to model_checkpoint.h5
# Epoch 997/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0425 - mean_squared_error: 0.0425 - val_loss: 0.1336 - val_mean_squared_error: 0.1336
#
# Epoch 00997: val_loss improved from 0.13405 to 0.13357, saving model to model_checkpoint.h5
# Epoch 998/80000
# 6/6 [==============================] - 0s 67ms/step - loss: 0.0424 - mean_squared_error: 0.0424 - val_loss: 0.1331 - val_mean_squared_error: 0.1331
#
# Epoch 00998: val_loss improved from 0.13357 to 0.13308, saving model to model_checkpoint.h5
# Epoch 999/80000
# 6/6 [==============================] - 0s 56ms/step - loss: 0.0422 - mean_squared_error: 0.0422 - val_loss: 0.1326 - val_mean_squared_error: 0.1326
#
# Epoch 00999: val_loss improved from 0.13308 to 0.13260, saving model to model_checkpoint.h5
# Epoch 1000/80000
# 6/6 [==============================] - 0s 64ms/step - loss: 0.0420 - mean_squared_error: 0.0420 - val_loss: 0.1321 - val_mean_squared_error: 0.1321
#
# Epoch 01000: val_loss improved from 0.13260 to 0.13212, saving model to model_checkpoint.h5
# Epoch 1001/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0419 - mean_squared_error: 0.0419 - val_loss: 0.1316 - val_mean_squared_error: 0.1316
#
# Epoch 01001: val_loss improved from 0.13212 to 0.13163, saving model to model_checkpoint.h5
# Epoch 1002/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0417 - mean_squared_error: 0.0417 - val_loss: 0.1312 - val_mean_squared_error: 0.1312
#
# Epoch 01002: val_loss improved from 0.13163 to 0.13115, saving model to model_checkpoint.h5
# Epoch 1003/80000
# 6/6 [==============================] - 0s 56ms/step - loss: 0.0416 - mean_squared_error: 0.0416 - val_loss: 0.1307 - val_mean_squared_error: 0.1307
#
# Epoch 01003: val_loss improved from 0.13115 to 0.13067, saving model to model_checkpoint.h5
# Epoch 1004/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0414 - mean_squared_error: 0.0414 - val_loss: 0.1302 - val_mean_squared_error: 0.1302
#
# Epoch 01004: val_loss improved from 0.13067 to 0.13020, saving model to model_checkpoint.h5
# Epoch 1005/80000
# 6/6 [==============================] - 0s 57ms/step - loss: 0.0413 - mean_squared_error: 0.0413 - val_loss: 0.1297 - val_mean_squared_error: 0.1297
#
# Epoch 01005: val_loss improved from 0.13020 to 0.12972, saving model to model_checkpoint.h5
# Epoch 1006/80000
# 6/6 [==============================] - 0s 77ms/step - loss: 0.0411 - mean_squared_error: 0.0411 - val_loss: 0.1292 - val_mean_squared_error: 0.1292
#
# Epoch 01006: val_loss improved from 0.12972 to 0.12924, saving model to model_checkpoint.h5
# Epoch 1007/80000
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0410 - mean_squared_error: 0.0410 - val_loss: 0.1288 - val_mean_squared_error: 0.1288
#
# Epoch 01007: val_loss improved from 0.12924 to 0.12877, saving model to model_checkpoint.h5
# Epoch 1008/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0408 - mean_squared_error: 0.0408 - val_loss: 0.1283 - val_mean_squared_error: 0.1283
#
# Epoch 01008: val_loss improved from 0.12877 to 0.12829, saving model to model_checkpoint.h5
# Epoch 1009/80000
# 6/6 [==============================] - 0s 69ms/step - loss: 0.0407 - mean_squared_error: 0.0407 - val_loss: 0.1278 - val_mean_squared_error: 0.1278
#
# Epoch 01009: val_loss improved from 0.12829 to 0.12782, saving model to model_checkpoint.h5
# Epoch 1010/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0405 - mean_squared_error: 0.0405 - val_loss: 0.1274 - val_mean_squared_error: 0.1274
#
# Epoch 01010: val_loss improved from 0.12782 to 0.12735, saving model to model_checkpoint.h5
# Epoch 1011/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0404 - mean_squared_error: 0.0404 - val_loss: 0.1269 - val_mean_squared_error: 0.1269
#
# Epoch 01011: val_loss improved from 0.12735 to 0.12688, saving model to model_checkpoint.h5
# Epoch 1012/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0402 - mean_squared_error: 0.0402 - val_loss: 0.1264 - val_mean_squared_error: 0.1264
#
# Epoch 01012: val_loss improved from 0.12688 to 0.12641, saving model to model_checkpoint.h5
# Epoch 1013/80000
# 6/6 [==============================] - 0s 56ms/step - loss: 0.0401 - mean_squared_error: 0.0401 - val_loss: 0.1259 - val_mean_squared_error: 0.1259
#
# Epoch 01013: val_loss improved from 0.12641 to 0.12594, saving model to model_checkpoint.h5
# Epoch 1014/80000
# 6/6 [==============================] - 0s 65ms/step - loss: 0.0399 - mean_squared_error: 0.0399 - val_loss: 0.1255 - val_mean_squared_error: 0.1255
#
# Epoch 01014: val_loss improved from 0.12594 to 0.12548, saving model to model_checkpoint.h5
# Epoch 1015/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0398 - mean_squared_error: 0.0398 - val_loss: 0.1250 - val_mean_squared_error: 0.1250
#
# Epoch 01015: val_loss improved from 0.12548 to 0.12501, saving model to model_checkpoint.h5
# Epoch 1016/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0396 - mean_squared_error: 0.0396 - val_loss: 0.1245 - val_mean_squared_error: 0.1245
#
# Epoch 01016: val_loss improved from 0.12501 to 0.12455, saving model to model_checkpoint.h5
# Epoch 1017/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0395 - mean_squared_error: 0.0395 - val_loss: 0.1241 - val_mean_squared_error: 0.1241
#
# Epoch 01017: val_loss improved from 0.12455 to 0.12408, saving model to model_checkpoint.h5
# Epoch 1018/80000
# 6/6 [==============================] - 0s 58ms/step - loss: 0.0393 - mean_squared_error: 0.0393 - val_loss: 0.1236 - val_mean_squared_error: 0.1236
#
# Epoch 01018: val_loss improved from 0.12408 to 0.12362, saving model to model_checkpoint.h5
# Epoch 1019/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0392 - mean_squared_error: 0.0392 - val_loss: 0.1232 - val_mean_squared_error: 0.1232
#
# Epoch 01019: val_loss improved from 0.12362 to 0.12316, saving model to model_checkpoint.h5
# Epoch 1020/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0390 - mean_squared_error: 0.0390 - val_loss: 0.1227 - val_mean_squared_error: 0.1227
#
# Epoch 01020: val_loss improved from 0.12316 to 0.12270, saving model to model_checkpoint.h5
# Epoch 1021/80000
# 6/6 [==============================] - 0s 71ms/step - loss: 0.0389 - mean_squared_error: 0.0389 - val_loss: 0.1222 - val_mean_squared_error: 0.1222
#
# Epoch 01021: val_loss improved from 0.12270 to 0.12224, saving model to model_checkpoint.h5
# Epoch 1022/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0387 - mean_squared_error: 0.0387 - val_loss: 0.1218 - val_mean_squared_error: 0.1218
#
# Epoch 01022: val_loss improved from 0.12224 to 0.12178, saving model to model_checkpoint.h5
# Epoch 1023/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0386 - mean_squared_error: 0.0386 - val_loss: 0.1213 - val_mean_squared_error: 0.1213
#
# Epoch 01023: val_loss improved from 0.12178 to 0.12132, saving model to model_checkpoint.h5
# Epoch 1024/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0384 - mean_squared_error: 0.0384 - val_loss: 0.1209 - val_mean_squared_error: 0.1209
#
# Epoch 01024: val_loss improved from 0.12132 to 0.12087, saving model to model_checkpoint.h5
# Epoch 1025/80000
# 6/6 [==============================] - 0s 64ms/step - loss: 0.0383 - mean_squared_error: 0.0383 - val_loss: 0.1204 - val_mean_squared_error: 0.1204
#
# Epoch 01025: val_loss improved from 0.12087 to 0.12041, saving model to model_checkpoint.h5
# Epoch 1026/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0382 - mean_squared_error: 0.0382 - val_loss: 0.1200 - val_mean_squared_error: 0.1200
#
# Epoch 01026: val_loss improved from 0.12041 to 0.11996, saving model to model_checkpoint.h5
# Epoch 1027/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0380 - mean_squared_error: 0.0380 - val_loss: 0.1195 - val_mean_squared_error: 0.1195
#
# Epoch 01027: val_loss improved from 0.11996 to 0.11951, saving model to model_checkpoint.h5
# Epoch 1028/80000
# 6/6 [==============================] - 0s 65ms/step - loss: 0.0379 - mean_squared_error: 0.0379 - val_loss: 0.1191 - val_mean_squared_error: 0.1191
#
# Epoch 01028: val_loss improved from 0.11951 to 0.11906, saving model to model_checkpoint.h5
# Epoch 1029/80000
# 6/6 [==============================] - 0s 72ms/step - loss: 0.0377 - mean_squared_error: 0.0377 - val_loss: 0.1186 - val_mean_squared_error: 0.1186
#
# Epoch 01029: val_loss improved from 0.11906 to 0.11861, saving model to model_checkpoint.h5
# Epoch 1030/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0376 - mean_squared_error: 0.0376 - val_loss: 0.1182 - val_mean_squared_error: 0.1182
#
# Epoch 01030: val_loss improved from 0.11861 to 0.11816, saving model to model_checkpoint.h5
# Epoch 1031/80000
# 6/6 [==============================] - 0s 58ms/step - loss: 0.0374 - mean_squared_error: 0.0374 - val_loss: 0.1177 - val_mean_squared_error: 0.1177
#
# Epoch 01031: val_loss improved from 0.11816 to 0.11771, saving model to model_checkpoint.h5
# Epoch 1032/80000
# 6/6 [==============================] - 0s 53ms/step - loss: 0.0373 - mean_squared_error: 0.0373 - val_loss: 0.1173 - val_mean_squared_error: 0.1173
#
# Epoch 01032: val_loss improved from 0.11771 to 0.11726, saving model to model_checkpoint.h5
# Epoch 1033/80000
# 6/6 [==============================] - 0s 70ms/step - loss: 0.0371 - mean_squared_error: 0.0371 - val_loss: 0.1168 - val_mean_squared_error: 0.1168
#
# Epoch 01033: val_loss improved from 0.11726 to 0.11682, saving model to model_checkpoint.h5
# Epoch 1034/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0370 - mean_squared_error: 0.0370 - val_loss: 0.1164 - val_mean_squared_error: 0.1164
#
# Epoch 01034: val_loss improved from 0.11682 to 0.11637, saving model to model_checkpoint.h5
# Epoch 1035/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0369 - mean_squared_error: 0.0369 - val_loss: 0.1159 - val_mean_squared_error: 0.1159
#
# Epoch 01035: val_loss improved from 0.11637 to 0.11593, saving model to model_checkpoint.h5
# Epoch 1036/80000
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0367 - mean_squared_error: 0.0367 - val_loss: 0.1155 - val_mean_squared_error: 0.1155
#
# Epoch 01036: val_loss improved from 0.11593 to 0.11548, saving model to model_checkpoint.h5
# Epoch 1037/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0366 - mean_squared_error: 0.0366 - val_loss: 0.1150 - val_mean_squared_error: 0.1150
#
# Epoch 01037: val_loss improved from 0.11548 to 0.11504, saving model to model_checkpoint.h5
# Epoch 1038/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0364 - mean_squared_error: 0.0364 - val_loss: 0.1146 - val_mean_squared_error: 0.1146
#
# Epoch 01038: val_loss improved from 0.11504 to 0.11460, saving model to model_checkpoint.h5
# Epoch 1039/80000
# 6/6 [==============================] - 0s 58ms/step - loss: 0.0363 - mean_squared_error: 0.0363 - val_loss: 0.1142 - val_mean_squared_error: 0.1142
#
# Epoch 01039: val_loss improved from 0.11460 to 0.11416, saving model to model_checkpoint.h5
# Epoch 1040/80000
# 6/6 [==============================] - 0s 64ms/step - loss: 0.0362 - mean_squared_error: 0.0362 - val_loss: 0.1137 - val_mean_squared_error: 0.1137
#
# Epoch 01040: val_loss improved from 0.11416 to 0.11373, saving model to model_checkpoint.h5
# Epoch 1041/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0360 - mean_squared_error: 0.0360 - val_loss: 0.1133 - val_mean_squared_error: 0.1133
#
# Epoch 01041: val_loss improved from 0.11373 to 0.11329, saving model to model_checkpoint.h5
# Epoch 1042/80000
# 6/6 [==============================] - 0s 56ms/step - loss: 0.0359 - mean_squared_error: 0.0359 - val_loss: 0.1129 - val_mean_squared_error: 0.1129
#
# Epoch 01042: val_loss improved from 0.11329 to 0.11285, saving model to model_checkpoint.h5
# Epoch 1043/80000
# 6/6 [==============================] - 0s 64ms/step - loss: 0.0358 - mean_squared_error: 0.0358 - val_loss: 0.1124 - val_mean_squared_error: 0.1124
#
# Epoch 01043: val_loss improved from 0.11285 to 0.11242, saving model to model_checkpoint.h5
# Epoch 1044/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0356 - mean_squared_error: 0.0356 - val_loss: 0.1120 - val_mean_squared_error: 0.1120
#
# Epoch 01044: val_loss improved from 0.11242 to 0.11198, saving model to model_checkpoint.h5
# Epoch 1045/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0355 - mean_squared_error: 0.0355 - val_loss: 0.1116 - val_mean_squared_error: 0.1116
#
# Epoch 01045: val_loss improved from 0.11198 to 0.11155, saving model to model_checkpoint.h5
# Epoch 1046/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0353 - mean_squared_error: 0.0353 - val_loss: 0.1111 - val_mean_squared_error: 0.1111
#
# Epoch 01046: val_loss improved from 0.11155 to 0.11112, saving model to model_checkpoint.h5
# Epoch 1047/80000
# 6/6 [==============================] - 0s 68ms/step - loss: 0.0352 - mean_squared_error: 0.0352 - val_loss: 0.1107 - val_mean_squared_error: 0.1107
#
# Epoch 01047: val_loss improved from 0.11112 to 0.11069, saving model to model_checkpoint.h5
# Epoch 1048/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.1103 - val_mean_squared_error: 0.1103
#
# Epoch 01048: val_loss improved from 0.11069 to 0.11026, saving model to model_checkpoint.h5
# Epoch 1049/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0349 - mean_squared_error: 0.0349 - val_loss: 0.1098 - val_mean_squared_error: 0.1098
#
# Epoch 01049: val_loss improved from 0.11026 to 0.10983, saving model to model_checkpoint.h5
# Epoch 1050/80000
# 6/6 [==============================] - 0s 57ms/step - loss: 0.0348 - mean_squared_error: 0.0348 - val_loss: 0.1094 - val_mean_squared_error: 0.1094
#
# Epoch 01050: val_loss improved from 0.10983 to 0.10941, saving model to model_checkpoint.h5
# Epoch 1051/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0347 - mean_squared_error: 0.0347 - val_loss: 0.1090 - val_mean_squared_error: 0.1090
#
# Epoch 01051: val_loss improved from 0.10941 to 0.10898, saving model to model_checkpoint.h5
# Epoch 1052/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0345 - mean_squared_error: 0.0345 - val_loss: 0.1086 - val_mean_squared_error: 0.1086
#
# Epoch 01052: val_loss improved from 0.10898 to 0.10855, saving model to model_checkpoint.h5
# Epoch 1053/80000
# 6/6 [==============================] - 0s 69ms/step - loss: 0.0344 - mean_squared_error: 0.0344 - val_loss: 0.1081 - val_mean_squared_error: 0.1081
#
# Epoch 01053: val_loss improved from 0.10855 to 0.10813, saving model to model_checkpoint.h5
# Epoch 1054/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0343 - mean_squared_error: 0.0343 - val_loss: 0.1077 - val_mean_squared_error: 0.1077
#
# Epoch 01054: val_loss improved from 0.10813 to 0.10771, saving model to model_checkpoint.h5
# Epoch 1055/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0341 - mean_squared_error: 0.0341 - val_loss: 0.1073 - val_mean_squared_error: 0.1073
#
# Epoch 01055: val_loss improved from 0.10771 to 0.10729, saving model to model_checkpoint.h5
# Epoch 1056/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0340 - mean_squared_error: 0.0340 - val_loss: 0.1069 - val_mean_squared_error: 0.1069
#
# Epoch 01056: val_loss improved from 0.10729 to 0.10687, saving model to model_checkpoint.h5
# Epoch 1057/80000
# 6/6 [==============================] - 0s 77ms/step - loss: 0.0339 - mean_squared_error: 0.0339 - val_loss: 0.1064 - val_mean_squared_error: 0.1064
#
# Epoch 01057: val_loss improved from 0.10687 to 0.10645, saving model to model_checkpoint.h5
# Epoch 1058/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0337 - mean_squared_error: 0.0337 - val_loss: 0.1060 - val_mean_squared_error: 0.1060
#
# Epoch 01058: val_loss improved from 0.10645 to 0.10603, saving model to model_checkpoint.h5
# Epoch 1059/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0336 - mean_squared_error: 0.0336 - val_loss: 0.1056 - val_mean_squared_error: 0.1056
#
# Epoch 01059: val_loss improved from 0.10603 to 0.10561, saving model to model_checkpoint.h5
# Epoch 1060/80000
# 6/6 [==============================] - 0s 72ms/step - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.1052 - val_mean_squared_error: 0.1052
#
# Epoch 01060: val_loss improved from 0.10561 to 0.10519, saving model to model_checkpoint.h5
# Epoch 1061/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0333 - mean_squared_error: 0.0333 - val_loss: 0.1048 - val_mean_squared_error: 0.1048
#
# Epoch 01061: val_loss improved from 0.10519 to 0.10478, saving model to model_checkpoint.h5
# Epoch 1062/80000
# 6/6 [==============================] - 0s 64ms/step - loss: 0.0332 - mean_squared_error: 0.0332 - val_loss: 0.1044 - val_mean_squared_error: 0.1044
#
# Epoch 01062: val_loss improved from 0.10478 to 0.10436, saving model to model_checkpoint.h5
# Epoch 1063/80000
# 6/6 [==============================] - 0s 65ms/step - loss: 0.0331 - mean_squared_error: 0.0331 - val_loss: 0.1040 - val_mean_squared_error: 0.1040
#
# Epoch 01063: val_loss improved from 0.10436 to 0.10395, saving model to model_checkpoint.h5
# Epoch 1064/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0329 - mean_squared_error: 0.0329 - val_loss: 0.1035 - val_mean_squared_error: 0.1035
#
# Epoch 01064: val_loss improved from 0.10395 to 0.10354, saving model to model_checkpoint.h5
# Epoch 1065/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0328 - mean_squared_error: 0.0328 - val_loss: 0.1031 - val_mean_squared_error: 0.1031
#
# Epoch 01065: val_loss improved from 0.10354 to 0.10313, saving model to model_checkpoint.h5
# Epoch 1066/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0327 - mean_squared_error: 0.0327 - val_loss: 0.1027 - val_mean_squared_error: 0.1027
#
# Epoch 01066: val_loss improved from 0.10313 to 0.10272, saving model to model_checkpoint.h5
# Epoch 1067/80000
# 6/6 [==============================] - 0s 57ms/step - loss: 0.0326 - mean_squared_error: 0.0326 - val_loss: 0.1023 - val_mean_squared_error: 0.1023
#
# Epoch 01067: val_loss improved from 0.10272 to 0.10231, saving model to model_checkpoint.h5
# Epoch 1068/80000
# 6/6 [==============================] - 0s 53ms/step - loss: 0.0324 - mean_squared_error: 0.0324 - val_loss: 0.1019 - val_mean_squared_error: 0.1019
#
# Epoch 01068: val_loss improved from 0.10231 to 0.10190, saving model to model_checkpoint.h5
# Epoch 1069/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0323 - mean_squared_error: 0.0323 - val_loss: 0.1015 - val_mean_squared_error: 0.1015
#
# Epoch 01069: val_loss improved from 0.10190 to 0.10150, saving model to model_checkpoint.h5
# Epoch 1070/80000
# 6/6 [==============================] - 0s 64ms/step - loss: 0.0322 - mean_squared_error: 0.0322 - val_loss: 0.1011 - val_mean_squared_error: 0.1011
#
# Epoch 01070: val_loss improved from 0.10150 to 0.10109, saving model to model_checkpoint.h5
# Epoch 1071/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0320 - mean_squared_error: 0.0320 - val_loss: 0.1007 - val_mean_squared_error: 0.1007
#
# Epoch 01071: val_loss improved from 0.10109 to 0.10069, saving model to model_checkpoint.h5
# Epoch 1072/80000
# 6/6 [==============================] - 0s 65ms/step - loss: 0.0319 - mean_squared_error: 0.0319 - val_loss: 0.1003 - val_mean_squared_error: 0.1003
#
# Epoch 01072: val_loss improved from 0.10069 to 0.10028, saving model to model_checkpoint.h5
# Epoch 1073/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0318 - mean_squared_error: 0.0318 - val_loss: 0.0999 - val_mean_squared_error: 0.0999
#
# Epoch 01073: val_loss improved from 0.10028 to 0.09988, saving model to model_checkpoint.h5
# Epoch 1074/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0317 - mean_squared_error: 0.0317 - val_loss: 0.0995 - val_mean_squared_error: 0.0995
#
# Epoch 01074: val_loss improved from 0.09988 to 0.09948, saving model to model_checkpoint.h5
# Epoch 1075/80000
# 6/6 [==============================] - 0s 57ms/step - loss: 0.0315 - mean_squared_error: 0.0315 - val_loss: 0.0991 - val_mean_squared_error: 0.0991
#
# Epoch 01075: val_loss improved from 0.09948 to 0.09908, saving model to model_checkpoint.h5
# Epoch 1076/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0314 - mean_squared_error: 0.0314 - val_loss: 0.0987 - val_mean_squared_error: 0.0987
#
# Epoch 01076: val_loss improved from 0.09908 to 0.09868, saving model to model_checkpoint.h5
# Epoch 1077/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0313 - mean_squared_error: 0.0313 - val_loss: 0.0983 - val_mean_squared_error: 0.0983
#
# Epoch 01077: val_loss improved from 0.09868 to 0.09828, saving model to model_checkpoint.h5
# Epoch 1078/80000
# 6/6 [==============================] - 0s 65ms/step - loss: 0.0312 - mean_squared_error: 0.0312 - val_loss: 0.0979 - val_mean_squared_error: 0.0979
#
# Epoch 01078: val_loss improved from 0.09828 to 0.09789, saving model to model_checkpoint.h5
# Epoch 1079/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0310 - mean_squared_error: 0.0310 - val_loss: 0.0975 - val_mean_squared_error: 0.0975
#
# Epoch 01079: val_loss improved from 0.09789 to 0.09749, saving model to model_checkpoint.h5
# Epoch 1080/80000
# 6/6 [==============================] - 0s 65ms/step - loss: 0.0309 - mean_squared_error: 0.0309 - val_loss: 0.0971 - val_mean_squared_error: 0.0971
#
# Epoch 01080: val_loss improved from 0.09749 to 0.09710, saving model to model_checkpoint.h5
# Epoch 1081/80000
# 6/6 [==============================] - 0s 64ms/step - loss: 0.0308 - mean_squared_error: 0.0308 - val_loss: 0.0967 - val_mean_squared_error: 0.0967
#
# Epoch 01081: val_loss improved from 0.09710 to 0.09670, saving model to model_checkpoint.h5
# Epoch 1082/80000
# 6/6 [==============================] - 0s 65ms/step - loss: 0.0307 - mean_squared_error: 0.0307 - val_loss: 0.0963 - val_mean_squared_error: 0.0963
#
# Epoch 01082: val_loss improved from 0.09670 to 0.09631, saving model to model_checkpoint.h5
# Epoch 1083/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0306 - mean_squared_error: 0.0306 - val_loss: 0.0959 - val_mean_squared_error: 0.0959
#
# Epoch 01083: val_loss improved from 0.09631 to 0.09592, saving model to model_checkpoint.h5
# Epoch 1084/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0304 - mean_squared_error: 0.0304 - val_loss: 0.0955 - val_mean_squared_error: 0.0955
#
# Epoch 01084: val_loss improved from 0.09592 to 0.09553, saving model to model_checkpoint.h5
# Epoch 1085/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0303 - mean_squared_error: 0.0303 - val_loss: 0.0951 - val_mean_squared_error: 0.0951
#
# Epoch 01085: val_loss improved from 0.09553 to 0.09514, saving model to model_checkpoint.h5
# Epoch 1086/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0302 - mean_squared_error: 0.0302 - val_loss: 0.0948 - val_mean_squared_error: 0.0948
#
# Epoch 01086: val_loss improved from 0.09514 to 0.09475, saving model to model_checkpoint.h5
# Epoch 1087/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0301 - mean_squared_error: 0.0301 - val_loss: 0.0944 - val_mean_squared_error: 0.0944
#
# Epoch 01087: val_loss improved from 0.09475 to 0.09436, saving model to model_checkpoint.h5
# Epoch 1088/80000
# 6/6 [==============================] - 0s 58ms/step - loss: 0.0299 - mean_squared_error: 0.0299 - val_loss: 0.0940 - val_mean_squared_error: 0.0940
#
# Epoch 01088: val_loss improved from 0.09436 to 0.09398, saving model to model_checkpoint.h5
# Epoch 1089/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0298 - mean_squared_error: 0.0298 - val_loss: 0.0936 - val_mean_squared_error: 0.0936
#
# Epoch 01089: val_loss improved from 0.09398 to 0.09359, saving model to model_checkpoint.h5
# Epoch 1090/80000
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0297 - mean_squared_error: 0.0297 - val_loss: 0.0932 - val_mean_squared_error: 0.0932
#
# Epoch 01090: val_loss improved from 0.09359 to 0.09321, saving model to model_checkpoint.h5
# Epoch 1091/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0296 - mean_squared_error: 0.0296 - val_loss: 0.0928 - val_mean_squared_error: 0.0928
#
# Epoch 01091: val_loss improved from 0.09321 to 0.09282, saving model to model_checkpoint.h5
# Epoch 1092/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0295 - mean_squared_error: 0.0295 - val_loss: 0.0924 - val_mean_squared_error: 0.0924
#
# Epoch 01092: val_loss improved from 0.09282 to 0.09244, saving model to model_checkpoint.h5
# Epoch 1093/80000
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0294 - mean_squared_error: 0.0294 - val_loss: 0.0921 - val_mean_squared_error: 0.0921
#
# Epoch 01093: val_loss improved from 0.09244 to 0.09206, saving model to model_checkpoint.h5
# Epoch 1094/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0292 - mean_squared_error: 0.0292 - val_loss: 0.0917 - val_mean_squared_error: 0.0917
#
# Epoch 01094: val_loss improved from 0.09206 to 0.09168, saving model to model_checkpoint.h5
# Epoch 1095/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0291 - mean_squared_error: 0.0291 - val_loss: 0.0913 - val_mean_squared_error: 0.0913
#
# Epoch 01095: val_loss improved from 0.09168 to 0.09130, saving model to model_checkpoint.h5
# Epoch 1096/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0290 - mean_squared_error: 0.0290 - val_loss: 0.0909 - val_mean_squared_error: 0.0909
#
# Epoch 01096: val_loss improved from 0.09130 to 0.09093, saving model to model_checkpoint.h5
# Epoch 1097/80000
# 6/6 [==============================] - 0s 73ms/step - loss: 0.0289 - mean_squared_error: 0.0289 - val_loss: 0.0905 - val_mean_squared_error: 0.0905
#
# Epoch 01097: val_loss improved from 0.09093 to 0.09055, saving model to model_checkpoint.h5
# Epoch 1098/80000
# 6/6 [==============================] - 0s 54ms/step - loss: 0.0288 - mean_squared_error: 0.0288 - val_loss: 0.0902 - val_mean_squared_error: 0.0902
#
# Epoch 01098: val_loss improved from 0.09055 to 0.09017, saving model to model_checkpoint.h5
# Epoch 1099/80000
# 6/6 [==============================] - 0s 70ms/step - loss: 0.0286 - mean_squared_error: 0.0286 - val_loss: 0.0898 - val_mean_squared_error: 0.0898
#
# Epoch 01099: val_loss improved from 0.09017 to 0.08980, saving model to model_checkpoint.h5
# Epoch 1100/80000
# 6/6 [==============================] - 0s 68ms/step - loss: 0.0285 - mean_squared_error: 0.0285 - val_loss: 0.0894 - val_mean_squared_error: 0.0894
#
# Epoch 01100: val_loss improved from 0.08980 to 0.08943, saving model to model_checkpoint.h5
# Epoch 1101/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0284 - mean_squared_error: 0.0284 - val_loss: 0.0891 - val_mean_squared_error: 0.0891
#
# Epoch 01101: val_loss improved from 0.08943 to 0.08905, saving model to model_checkpoint.h5
# Epoch 1102/80000
# 6/6 [==============================] - 0s 70ms/step - loss: 0.0283 - mean_squared_error: 0.0283 - val_loss: 0.0887 - val_mean_squared_error: 0.0887
#
# Epoch 01102: val_loss improved from 0.08905 to 0.08868, saving model to model_checkpoint.h5
# Epoch 1103/80000
# 6/6 [==============================] - 0s 57ms/step - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0883 - val_mean_squared_error: 0.0883
#
# Epoch 01103: val_loss improved from 0.08868 to 0.08831, saving model to model_checkpoint.h5
# Epoch 1104/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0879 - val_mean_squared_error: 0.0879
#
# Epoch 01104: val_loss improved from 0.08831 to 0.08794, saving model to model_checkpoint.h5
# Epoch 1105/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0876 - val_mean_squared_error: 0.0876
#
# Epoch 01105: val_loss improved from 0.08794 to 0.08757, saving model to model_checkpoint.h5
# Epoch 1106/80000
# 6/6 [==============================] - 0s 65ms/step - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0872 - val_mean_squared_error: 0.0872
#
# Epoch 01106: val_loss improved from 0.08757 to 0.08721, saving model to model_checkpoint.h5
# Epoch 1107/80000
# 6/6 [==============================] - 0s 64ms/step - loss: 0.0277 - mean_squared_error: 0.0277 - val_loss: 0.0868 - val_mean_squared_error: 0.0868
#
# Epoch 01107: val_loss improved from 0.08721 to 0.08684, saving model to model_checkpoint.h5
# Epoch 1108/80000
# 6/6 [==============================] - 0s 68ms/step - loss: 0.0276 - mean_squared_error: 0.0276 - val_loss: 0.0865 - val_mean_squared_error: 0.0865
#
# Epoch 01108: val_loss improved from 0.08684 to 0.08647, saving model to model_checkpoint.h5
# Epoch 1109/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0275 - mean_squared_error: 0.0275 - val_loss: 0.0861 - val_mean_squared_error: 0.0861
#
# Epoch 01109: val_loss improved from 0.08647 to 0.08611, saving model to model_checkpoint.h5
# Epoch 1110/80000
# 6/6 [==============================] - 0s 67ms/step - loss: 0.0274 - mean_squared_error: 0.0274 - val_loss: 0.0857 - val_mean_squared_error: 0.0857
#
# Epoch 01110: val_loss improved from 0.08611 to 0.08575, saving model to model_checkpoint.h5
# Epoch 1111/80000
# 6/6 [==============================] - 0s 55ms/step - loss: 0.0273 - mean_squared_error: 0.0273 - val_loss: 0.0854 - val_mean_squared_error: 0.0854
#
# Epoch 01111: val_loss improved from 0.08575 to 0.08538, saving model to model_checkpoint.h5
# Epoch 1112/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0272 - mean_squared_error: 0.0272 - val_loss: 0.0850 - val_mean_squared_error: 0.0850
#
# Epoch 01112: val_loss improved from 0.08538 to 0.08502, saving model to model_checkpoint.h5
# Epoch 1113/80000
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0271 - mean_squared_error: 0.0271 - val_loss: 0.0847 - val_mean_squared_error: 0.0847
#
# Epoch 01113: val_loss improved from 0.08502 to 0.08466, saving model to model_checkpoint.h5
# Epoch 1114/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0269 - mean_squared_error: 0.0269 - val_loss: 0.0843 - val_mean_squared_error: 0.0843
#
# Epoch 01114: val_loss improved from 0.08466 to 0.08430, saving model to model_checkpoint.h5
# Epoch 1115/80000
# 6/6 [==============================] - 0s 57ms/step - loss: 0.0268 - mean_squared_error: 0.0268 - val_loss: 0.0839 - val_mean_squared_error: 0.0839
#
# Epoch 01115: val_loss improved from 0.08430 to 0.08395, saving model to model_checkpoint.h5
# Epoch 1116/80000
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0267 - mean_squared_error: 0.0267 - val_loss: 0.0836 - val_mean_squared_error: 0.0836
#
# Epoch 01116: val_loss improved from 0.08395 to 0.08359, saving model to model_checkpoint.h5
# Epoch 1117/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0266 - mean_squared_error: 0.0266 - val_loss: 0.0832 - val_mean_squared_error: 0.0832
#
# Epoch 01117: val_loss improved from 0.08359 to 0.08323, saving model to model_checkpoint.h5
# Epoch 1118/80000
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0265 - mean_squared_error: 0.0265 - val_loss: 0.0829 - val_mean_squared_error: 0.0829
#
# Epoch 01118: val_loss improved from 0.08323 to 0.08288, saving model to model_checkpoint.h5
# Epoch 1119/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0264 - mean_squared_error: 0.0264 - val_loss: 0.0825 - val_mean_squared_error: 0.0825
#
# Epoch 01119: val_loss improved from 0.08288 to 0.08253, saving model to model_checkpoint.h5
# Epoch 1120/80000
# 6/6 [==============================] - 0s 55ms/step - loss: 0.0263 - mean_squared_error: 0.0263 - val_loss: 0.0822 - val_mean_squared_error: 0.0822
#
# Epoch 01120: val_loss improved from 0.08253 to 0.08217, saving model to model_checkpoint.h5
# Epoch 1121/80000
# 6/6 [==============================] - 0s 68ms/step - loss: 0.0262 - mean_squared_error: 0.0262 - val_loss: 0.0818 - val_mean_squared_error: 0.0818
#
# Epoch 01121: val_loss improved from 0.08217 to 0.08182, saving model to model_checkpoint.h5
# Epoch 1122/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0261 - mean_squared_error: 0.0261 - val_loss: 0.0815 - val_mean_squared_error: 0.0815
#
# Epoch 01122: val_loss improved from 0.08182 to 0.08147, saving model to model_checkpoint.h5
# Epoch 1123/80000
# 6/6 [==============================] - 0s 71ms/step - loss: 0.0260 - mean_squared_error: 0.0260 - val_loss: 0.0811 - val_mean_squared_error: 0.0811
#
# Epoch 01123: val_loss improved from 0.08147 to 0.08112, saving model to model_checkpoint.h5
# Epoch 1124/80000
# 6/6 [==============================] - 0s 57ms/step - loss: 0.0259 - mean_squared_error: 0.0259 - val_loss: 0.0808 - val_mean_squared_error: 0.0808
#
# Epoch 01124: val_loss improved from 0.08112 to 0.08077, saving model to model_checkpoint.h5
# Epoch 1125/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0257 - mean_squared_error: 0.0257 - val_loss: 0.0804 - val_mean_squared_error: 0.0804
#
# Epoch 01125: val_loss improved from 0.08077 to 0.08042, saving model to model_checkpoint.h5
# Epoch 1126/80000
# 6/6 [==============================] - 0s 57ms/step - loss: 0.0256 - mean_squared_error: 0.0256 - val_loss: 0.0801 - val_mean_squared_error: 0.0801
#
# Epoch 01126: val_loss improved from 0.08042 to 0.08008, saving model to model_checkpoint.h5
# Epoch 1127/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0255 - mean_squared_error: 0.0255 - val_loss: 0.0797 - val_mean_squared_error: 0.0797
#
# Epoch 01127: val_loss improved from 0.08008 to 0.07973, saving model to model_checkpoint.h5
# Epoch 1128/80000
# 6/6 [==============================] - 0s 56ms/step - loss: 0.0254 - mean_squared_error: 0.0254 - val_loss: 0.0794 - val_mean_squared_error: 0.0794
#
# Epoch 01128: val_loss improved from 0.07973 to 0.07939, saving model to model_checkpoint.h5
# Epoch 1129/80000
# 6/6 [==============================] - 0s 58ms/step - loss: 0.0253 - mean_squared_error: 0.0253 - val_loss: 0.0790 - val_mean_squared_error: 0.0790
#
# Epoch 01129: val_loss improved from 0.07939 to 0.07904, saving model to model_checkpoint.h5
# Epoch 1130/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0252 - mean_squared_error: 0.0252 - val_loss: 0.0787 - val_mean_squared_error: 0.0787
#
# Epoch 01130: val_loss improved from 0.07904 to 0.07870, saving model to model_checkpoint.h5
# Epoch 1131/80000
# 6/6 [==============================] - 0s 70ms/step - loss: 0.0251 - mean_squared_error: 0.0251 - val_loss: 0.0784 - val_mean_squared_error: 0.0784
#
# Epoch 01131: val_loss improved from 0.07870 to 0.07836, saving model to model_checkpoint.h5
# Epoch 1132/80000
# 6/6 [==============================] - 0s 58ms/step - loss: 0.0250 - mean_squared_error: 0.0250 - val_loss: 0.0780 - val_mean_squared_error: 0.0780
#
# Epoch 01132: val_loss improved from 0.07836 to 0.07802, saving model to model_checkpoint.h5
# Epoch 1133/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0249 - mean_squared_error: 0.0249 - val_loss: 0.0777 - val_mean_squared_error: 0.0777
#
# Epoch 01133: val_loss improved from 0.07802 to 0.07768, saving model to model_checkpoint.h5
# Epoch 1134/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0248 - mean_squared_error: 0.0248 - val_loss: 0.0773 - val_mean_squared_error: 0.0773
#
# Epoch 01134: val_loss improved from 0.07768 to 0.07734, saving model to model_checkpoint.h5
# Epoch 1135/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0247 - mean_squared_error: 0.0247 - val_loss: 0.0770 - val_mean_squared_error: 0.0770
#
# Epoch 01135: val_loss improved from 0.07734 to 0.07700, saving model to model_checkpoint.h5
# Epoch 1136/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 0.0767 - val_mean_squared_error: 0.0767
#
# Epoch 01136: val_loss improved from 0.07700 to 0.07667, saving model to model_checkpoint.h5
# Epoch 1137/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0245 - mean_squared_error: 0.0245 - val_loss: 0.0763 - val_mean_squared_error: 0.0763
#
# Epoch 01137: val_loss improved from 0.07667 to 0.07633, saving model to model_checkpoint.h5
# Epoch 1138/80000
# 6/6 [==============================] - 0s 65ms/step - loss: 0.0244 - mean_squared_error: 0.0244 - val_loss: 0.0760 - val_mean_squared_error: 0.0760
#
# Epoch 01138: val_loss improved from 0.07633 to 0.07600, saving model to model_checkpoint.h5
# Epoch 1139/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.0757 - val_mean_squared_error: 0.0757
#
# Epoch 01139: val_loss improved from 0.07600 to 0.07566, saving model to model_checkpoint.h5
# Epoch 1140/80000
# 6/6 [==============================] - 0s 64ms/step - loss: 0.0242 - mean_squared_error: 0.0242 - val_loss: 0.0753 - val_mean_squared_error: 0.0753
#
# Epoch 01140: val_loss improved from 0.07566 to 0.07533, saving model to model_checkpoint.h5
# Epoch 1141/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 0.0750 - val_mean_squared_error: 0.0750
#
# Epoch 01141: val_loss improved from 0.07533 to 0.07500, saving model to model_checkpoint.h5
# Epoch 1142/80000
# 6/6 [==============================] - 0s 78ms/step - loss: 0.0240 - mean_squared_error: 0.0240 - val_loss: 0.0747 - val_mean_squared_error: 0.0747
#
# Epoch 01142: val_loss improved from 0.07500 to 0.07467, saving model to model_checkpoint.h5
# Epoch 1143/80000
# 6/6 [==============================] - 0s 73ms/step - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 0.0743 - val_mean_squared_error: 0.0743
#
# Epoch 01143: val_loss improved from 0.07467 to 0.07434, saving model to model_checkpoint.h5
# Epoch 1144/80000
# 6/6 [==============================] - 0s 64ms/step - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 0.0740 - val_mean_squared_error: 0.0740
#
# Epoch 01144: val_loss improved from 0.07434 to 0.07401, saving model to model_checkpoint.h5
# Epoch 1145/80000
# 6/6 [==============================] - 0s 65ms/step - loss: 0.0237 - mean_squared_error: 0.0237 - val_loss: 0.0737 - val_mean_squared_error: 0.0737
#
# Epoch 01145: val_loss improved from 0.07401 to 0.07369, saving model to model_checkpoint.h5
# Epoch 1146/80000
# 6/6 [==============================] - 0s 57ms/step - loss: 0.0236 - mean_squared_error: 0.0236 - val_loss: 0.0734 - val_mean_squared_error: 0.0734
#
# Epoch 01146: val_loss improved from 0.07369 to 0.07336, saving model to model_checkpoint.h5
# Epoch 1147/80000
# 6/6 [==============================] - 0s 58ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.0730 - val_mean_squared_error: 0.0730
#
# Epoch 01147: val_loss improved from 0.07336 to 0.07303, saving model to model_checkpoint.h5
# Epoch 1148/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0727 - val_mean_squared_error: 0.0727
#
# Epoch 01148: val_loss improved from 0.07303 to 0.07271, saving model to model_checkpoint.h5
# Epoch 1149/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0233 - mean_squared_error: 0.0233 - val_loss: 0.0724 - val_mean_squared_error: 0.0724
#
# Epoch 01149: val_loss improved from 0.07271 to 0.07239, saving model to model_checkpoint.h5
# Epoch 1150/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0721 - val_mean_squared_error: 0.0721
#
# Epoch 01150: val_loss improved from 0.07239 to 0.07206, saving model to model_checkpoint.h5
# Epoch 1151/80000
# 6/6 [==============================] - 0s 58ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0717 - val_mean_squared_error: 0.0717
#
# Epoch 01151: val_loss improved from 0.07206 to 0.07174, saving model to model_checkpoint.h5
# Epoch 1152/80000
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0714 - val_mean_squared_error: 0.0714
#
# Epoch 01152: val_loss improved from 0.07174 to 0.07142, saving model to model_checkpoint.h5
# Epoch 1153/80000
# 6/6 [==============================] - 0s 65ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0711 - val_mean_squared_error: 0.0711
#
# Epoch 01153: val_loss improved from 0.07142 to 0.07110, saving model to model_checkpoint.h5
# Epoch 1154/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0708 - val_mean_squared_error: 0.0708
#
# Epoch 01154: val_loss improved from 0.07110 to 0.07078, saving model to model_checkpoint.h5
# Epoch 1155/80000
# 6/6 [==============================] - 0s 67ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0705 - val_mean_squared_error: 0.0705
#
# Epoch 01155: val_loss improved from 0.07078 to 0.07047, saving model to model_checkpoint.h5
# Epoch 1156/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0702 - val_mean_squared_error: 0.0702
#
# Epoch 01156: val_loss improved from 0.07047 to 0.07015, saving model to model_checkpoint.h5
# Epoch 1157/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0698 - val_mean_squared_error: 0.0698
#
# ...
#
# Epoch 02157: val_loss improved from 0.00215 to 0.00215, saving model to model_checkpoint.h5
# Epoch 2158/80000
# 6/6 [==============================] - 0s 58ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02158: val_loss improved from 0.00215 to 0.00215, saving model to model_checkpoint.h5
# Epoch 2159/80000
# 6/6 [==============================] - 0s 64ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02159: val_loss improved from 0.00215 to 0.00215, saving model to model_checkpoint.h5
# Epoch 2160/80000
# 6/6 [==============================] - 0s 64ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02160: val_loss improved from 0.00215 to 0.00215, saving model to model_checkpoint.h5
# Epoch 2161/80000
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02161: val_loss improved from 0.00215 to 0.00215, saving model to model_checkpoint.h5
# Epoch 2162/80000
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02162: val_loss improved from 0.00215 to 0.00215, saving model to model_checkpoint.h5
# Epoch 2163/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02163: val_loss improved from 0.00215 to 0.00215, saving model to model_checkpoint.h5
# Epoch 2164/80000
# 6/6 [==============================] - 0s 55ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02164: val_loss improved from 0.00215 to 0.00215, saving model to model_checkpoint.h5
# Epoch 2165/80000
# 6/6 [==============================] - 0s 57ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02165: val_loss improved from 0.00215 to 0.00215, saving model to model_checkpoint.h5
# Epoch 2166/80000
# 6/6 [==============================] - 0s 71ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02166: val_loss improved from 0.00215 to 0.00215, saving model to model_checkpoint.h5
# Epoch 2167/80000
# 6/6 [==============================] - 0s 64ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02167: val_loss improved from 0.00215 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2168/80000
# 6/6 [==============================] - 0s 72ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02168: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2169/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02169: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2170/80000
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02170: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2171/80000
# 6/6 [==============================] - 0s 65ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02171: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2172/80000
# 6/6 [==============================] - 0s 64ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02172: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2173/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02173: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2174/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02174: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2175/80000
# 6/6 [==============================] - 0s 67ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02175: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2176/80000
# 6/6 [==============================] - 0s 56ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02176: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2177/80000
# 6/6 [==============================] - 0s 65ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02177: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2178/80000
# 6/6 [==============================] - 0s 72ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02178: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2179/80000
# 6/6 [==============================] - 0s 64ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02179: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2180/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02180: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2181/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02181: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2182/80000
# 6/6 [==============================] - 0s 65ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02182: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2183/80000
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02183: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2184/80000
# 6/6 [==============================] - 0s 64ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02184: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2185/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02185: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2186/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02186: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2187/80000
# 6/6 [==============================] - 0s 67ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02187: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2188/80000
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02188: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2189/80000
# 6/6 [==============================] - 0s 69ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02189: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2190/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02190: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2191/80000
# 6/6 [==============================] - 0s 70ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02191: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2192/80000
# 6/6 [==============================] - 0s 56ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02192: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2193/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02193: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2194/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02194: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2195/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02195: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2196/80000
# 6/6 [==============================] - 0s 64ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02196: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2197/80000
# 6/6 [==============================] - 0s 69ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02197: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2198/80000
# 6/6 [==============================] - 0s 64ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02198: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2199/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02199: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2200/80000
# 6/6 [==============================] - 0s 57ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02200: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2201/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02201: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2202/80000
# 6/6 [==============================] - 0s 65ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02202: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2203/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02203: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2204/80000
# 6/6 [==============================] - 0s 57ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02204: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2205/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02205: val_loss improved from 0.00214 to 0.00214, saving model to model_checkpoint.h5
# Epoch 2206/80000
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02206: val_loss did not improve from 0.00214
# Epoch 2207/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02207: val_loss did not improve from 0.00214
# Epoch 2208/80000
# 6/6 [==============================] - 0s 58ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02208: val_loss did not improve from 0.00214
# Epoch 2209/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02209: val_loss did not improve from 0.00214
# Epoch 2210/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02210: val_loss did not improve from 0.00214
# Epoch 2211/80000
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02211: val_loss did not improve from 0.00214
# Epoch 2212/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02212: val_loss did not improve from 0.00214
# Epoch 2213/80000
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02213: val_loss did not improve from 0.00214
# Epoch 2214/80000
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02214: val_loss did not improve from 0.00214
# Epoch 2215/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02215: val_loss did not improve from 0.00214
# Epoch 2216/80000
# 6/6 [==============================] - 0s 67ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02216: val_loss did not improve from 0.00214
# Epoch 2217/80000
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02217: val_loss did not improve from 0.00214
# Epoch 2218/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02218: val_loss did not improve from 0.00214
# Epoch 2219/80000
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02219: val_loss did not improve from 0.00214
# Epoch 2220/80000
# 6/6 [==============================] - 0s 72ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02220: val_loss did not improve from 0.00214
# Epoch 2221/80000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 02221: val_loss did not improve from 0.00214

# %% [markdown]
# ## Visualize train and test loss

# %%
def visualize_loss(history, title):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(loss))
    plt.figure()
    plt.plot(epochs, loss, "b", label="Training loss")
    plt.plot(epochs, val_loss, "r", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()


visualize_loss(history, "Training and Validation Loss")

# %% [markdown]
# Checking variables

# %%
dataset_val
# Out:
# <BatchDataset shapes: ((None, None, 8), (None, 1)), types: (tf.float64, tf.float64)>

# %%
time_data = df_ann[date_time_key]
print(time_data)
# Out:
# 0       2020-04-14 13:00:00
# 1       2020-04-14 14:00:00
# 2       2020-04-14 15:00:00
# 3       2020-04-14 16:00:00
# 4       2020-04-14 17:00:00
#                ...
# 1736    2021-04-09 15:00:00
# 1737    2021-04-09 16:00:00
# 1738    2021-04-09 17:00:00
# 1739    2021-04-09 18:00:00
# 1740    2021-04-09 19:00:00
# Name: date, Length: 1741, dtype: object

# %%
print(train_split+sequence_length)
print(label_start)
# Out:
# 1422
# 1423

# %%
print(train_split)
# Out:
# 1392

# %% [markdown]
# Plot test close data

# %%
import matplotlib.ticker as ticker
dates_for_plot=time_data[label_start+sequence_length-1:] #Get testing data dates
print(dates_for_plot.shape)
t_data=df_ann["close"] # Get testing data close values
print(t_data[label_start+sequence_length-1:])
ax = plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(15))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(5))
plt.xticks(rotation=90,fontsize=10)
plt.subplots_adjust(top=51,bottom = 50)
plt.plot(t_data[label_start+sequence_length-1:])
# Out:
# (289,)
# date
# 2021-02-09 19:00:00    844.684998
# 2021-02-09 20:00:00    849.250000
# 2021-02-10 14:00:00    817.729980
# 2021-02-10 15:00:00    813.619995
# 2021-02-10 16:00:00    813.900024
#                           ...
# 2021-04-09 15:00:00    676.549988
# 2021-04-09 16:00:00    678.255005
# 2021-04-09 17:00:00    672.248474
# 2021-04-09 18:00:00    674.349976
# 2021-04-09 19:00:00    677.020020
# Name: close, Length: 289, dtype: float64

# %% [markdown]
# ## Predict
#
# Predict the data in the dataset and inverse scale it.

# %%
y_hat=[]
y_hat_un=[]
for x, y in dataset_val:
    x_num=x.numpy()
    #print(x_num)
    x_num_shape=x_num.shape
    print(x_num_shape)
    #print(x[x_num_shape[0]-1,:,:])
    for j in range(x_num_shape[0]):
      x_ten=x[j,:,:]
      #print(x_ten)
      x_ten_re=tf.reshape(x_ten, [1,past,selec.size], name=None)
      #print(x_ten_re)
      #print(model.predict(x_ten_re))
      y_=model.predict(x_ten_re)
      y_hat.append(y_)
      x_un=scaler.inverse_transform(pd.DataFrame(x_ten))
      y_scaled=np.zeros([selec.size,selec.size])
      y_scaled[0]=y_
      y_un=scaler.inverse_transform(pd.DataFrame(y_scaled))[0,0]
      y_hat_un.append(y_un)
      #print(x_un)
      #print(y_un)
      #input("Press Enter to continue...")
    #print(model.predict(x_ten))
    #print(y)

#x_ten=x[x_num_shape[0]-1,:,:]
#x_ten_re=tf.reshape(x_ten, [1,30,15], name=None)
#print(x_ten_re)
#x_num=x.numpy()
#x_num_shape=x_num.shape
#print(model.predict(x_ten_re))
#print(y[x_num_shape[0]-1])
# Out:
# (256, 30, 8)
# (33, 30, 8)

# %%
#print(y_hat)

# %%
print(len(y_hat))
# Out:
# 289

# %%
#Image_FORECASTING_LSTM_1_2_0
import numpy as np
y_hat_un_np=np.array(y_hat_un)
ax = plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(15))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(5))
plt.xticks(rotation=90,fontsize=10)
plt.subplots_adjust(top=51,bottom = 50)
plt.plot(dates_for_plot,y_hat_un_np[:],'c.',label="Prediction")
plt.plot(dates_for_plot,t_data[label_start+sequence_length-1:],'g*',label="Real")
variation=y_hat_un_np[:]-t_data[label_start+sequence_length-1:]
print(variation)
plt.legend()
# Out:
# date
# 2021-02-09 19:00:00   -28.940540
# 2021-02-09 20:00:00   -40.542760
# 2021-02-10 14:00:00   -16.111324
# 2021-02-10 15:00:00   -10.089602
# 2021-02-10 16:00:00   -10.279080
#                          ...
# 2021-04-09 15:00:00    -7.886153
# 2021-04-09 16:00:00   -13.216194
# 2021-04-09 17:00:00    -6.496846
# 2021-04-09 18:00:00    -7.721953
# 2021-04-09 19:00:00    -4.088718
# Name: close, Length: 289, dtype: float64

# %% [markdown]
# ## Aplication
#
# Compute the prediction for the given date and show the prediction and the real data.

# %%
from datetime import datetime
dt = datetime.strptime('2021-03-22 16:00:00', '%Y-%m-%d %H:%M:%S')
mask = (features_scaled_w_date['date'] <= str(dt))
#print(features_scaled_w_date.shape)
features_scaled_w_date_tensor=features_scaled_w_date.loc[mask]
#print(features_scaled_w_date_tensor.shape)
dates_plot=features_scaled_w_date_tensor.iloc[-sequence_length-future-1:,:]
features_scaled_w_date_tensor=features_scaled_w_date_tensor.iloc[-sequence_length-future-1:-future-1,:]
#print(features_scaled_w_date_tensor.head())
tensor_single=tf.convert_to_tensor(features_scaled_w_date_tensor.iloc[:,1:])
#print(tensor_single)
x_ten_re_s=tf.reshape(tensor_single, [1,past,selec.size], name=None)


y_s=model.predict(x_ten_re_s)
x_un_s=scaler.inverse_transform(features_scaled_w_date_tensor.iloc[:,1:])
y_target=scaler.inverse_transform(dates_plot.iloc[:,1:])[sequence_length+future,0]

y_scaled_single=np.zeros([selec.size,selec.size])
y_scaled_single[0]=y_s
y_un_single=scaler.inverse_transform(pd.DataFrame(y_scaled_single))[0,0]
#print(x_un_s)
#print(y_un_single)

x_for_plot=x_un_s[:,0]
#print(dates_plot.head())
dates_1=dates_plot['date']
ax = plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(5))
plt.xticks(rotation=90,fontsize=10)
plt.subplots_adjust(top=51,bottom = 50)
plt.plot(dates_1[0:sequence_length],x_for_plot)
print(dates_1.iloc[sequence_length+future])
plt.plot(dates_1.iloc[sequence_length+future],y_un_single,'bo',label="Prediction")
print(y_target)
plt.plot(dates_1.iloc[sequence_length+future],y_target,'ro',label="Real")
plt.legend()
# Out:
# 2021-03-22 16:00:00
# 690.2000732421875

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from math import sqrt
rmse = sqrt(mean_squared_error(t_data[label_start+sequence_length-1:], y_hat_un_np))
print('Test RMSE: %.3f' % rmse)
# Calculate MAE
mae = mean_absolute_error(t_data[label_start+sequence_length-1:], y_hat_un_np)
print('Test MAE: %.3f' % mae)
# r2
from sklearn.metrics import r2_score
test_r2 = r2_score(t_data[label_start+sequence_length-1:], y_hat_un_np)
print('Test r2: %.3f' % test_r2)
# Out:
# Test RMSE: 52.524
# Test MAE: 42.353
# Test r2: 0.244

# %%
print(x_un_s.shape)
# Out:
# (30, 8)

# %%
#print(dates_for_plot[0:1363])
y_hat_np=np.array(y_hat)
ax = plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(15))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(5))
plt.xticks(rotation=90,fontsize=10)
plt.subplots_adjust(top=51,bottom = 50)
print(y_hat_np.shape)
print(dates_for_plot.shape)
plt.plot(dates_for_plot,y_hat_np[:,0,0])
print(features.tail())
print(features.loc[label_start+sequence_length-1 : ,0])
plt.plot(dates_for_plot,features.loc[label_start+sequence_length-1 : ,0])
# Out:
# (289, 1, 1)
# (289,)
#                      date         0         1  ...         5         6         7
# 1736  2021-04-09 15:00:00  0.715179  0.707214  ...  0.716668  0.715299  0.713900
# 1737  2021-04-09 16:00:00  0.717440  0.708765  ...  0.716583  0.715428  0.714241
# 1738  2021-04-09 17:00:00  0.709473  0.708279  ...  0.714247  0.713955  0.713634
# 1739  2021-04-09 18:00:00  0.712261  0.703880  ...  0.714087  0.713181  0.712258
# 1740  2021-04-09 19:00:00  0.715802  0.706964  ...  0.716873  0.714677  0.712461
#
# [5 rows x 9 columns]
# 1452    0.938185
# 1453    0.944240
# 1454    0.902433
# 1455    0.896982
# 1456    0.897353
#           ...
# 1736    0.715179
# 1737    0.717440
# 1738    0.709473
# 1739    0.712261
# 1740    0.715802
# Name: 0, Length: 289, dtype: float64
